# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score, precision_score, recall_score

# ========== TEST/EVALUATION BLOCK ==========

# --- Prepare test environment and reload agent ---
test_env = RLenv('test', train_path=kdd_train, test_path=kdd_test,
                 formated_train_path=formated_train_path, formated_test_path=formated_test_path,
                 batch_size=1, iterations_episode=1)  # batch_size=1 for prediction
test_obs_size = test_env.X.shape[1]
test_defender_agent = Agent(defender_valid_actions, test_obs_size, gamma=0.99, hidden_size=128, hidden_layers=3)
test_defender_agent.load("models/defender")

# --- Load test data ---
states, labels = test_env.get_full()
print(f"Test set shape: {states.shape}, labels shape: {labels.shape}")

# --- Predict with defender agent ---
preds = []
for i in range(len(states)):
    action, *_ = test_defender_agent.act(states[i])
    preds.append(action)
preds = np.array(preds)

# --- Map true labels (one-hot) to attack_type indices ---
maped = []
for i in range(len(labels)):
    attack_name = test_env.attack_names[np.argmax(labels[i])]
    maped.append(test_env.attack_types.index(test_env.attack_map[attack_name]))
maped = np.array(maped)

# --- Sanity Checks ---
print("Attack types:", test_env.attack_types)
print("Sample mapped indices (true):", maped[:10])
print("Sample predictions:", preds[:10])

# --- Confusion Matrix and Per-Class Metrics ---
cm = confusion_matrix(maped, preds)
print("\nConfusion matrix (counts):")
print(cm)

# --- Normalize by true labels (rows) ---
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm_normalized = np.nan_to_num(cm_normalized)

# --- Plot normalized confusion matrix ---
plt.figure(figsize=(8, 6))
plt.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.colorbar(label='Fraction of True Labels')
tick_marks = np.arange(len(test_env.attack_types))
plt.xticks(tick_marks, test_env.attack_types, rotation=45)
plt.yticks(tick_marks, test_env.attack_types)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
for i in range(cm_normalized.shape[0]):
    for j in range(cm_normalized.shape[1]):
        plt.text(j, i, f"{cm_normalized[i, j]:.2f}",
                 ha="center", va="center",
                 color="white" if cm_normalized[i, j] > 0.5 else "black")
plt.tight_layout()
os.makedirs('results', exist_ok=True)
plt.savefig('results/normalized_confusion_matrix.png', dpi=300)
plt.show()

# --- Per-class report ---
report = classification_report(maped, preds, target_names=test_env.attack_types, digits=4)
print("\nClassification report:\n", report)

# --- Per-class F1 and custom table ---
true_labels = np.bincount(maped, minlength=len(test_env.attack_types))
preds = np.asarray(preds).astype(int).flatten()
estimated_labels = np.bincount(preds, minlength=len(test_env.attack_types))
estimated_correct_labels = np.zeros(len(test_env.attack_types), dtype=int)
for idx, a in enumerate(preds):
    if a == maped[idx]:
        estimated_correct_labels[a] += 1
outputs_df = pd.DataFrame(index=test_env.attack_types, columns=["Estimated", "Correct", "Total", "F1_score"])
for idx, att in enumerate(test_env.attack_types):
    f1 = f1_score(maped == idx, preds == idx)
    outputs_df.loc[att] = [
        estimated_labels[idx], estimated_correct_labels[idx], true_labels[idx], f1 * 100
    ]
print("\nCustom per-class summary:")
print(outputs_df)

# --- Overall metrics ---
print('\nPerformance on test data:')
print('Accuracy = {:.4f}'.format(accuracy_score(maped, preds)))
print('F1 = {:.4f}'.format(f1_score(maped, preds, average="weighted")))
print('Precision = {:.4f}'.format(precision_score(maped, preds, average="weighted")))
print('Recall = {:.4f}'.format(recall_score(maped, preds, average="weighted")))

# --- Bar chart for correct/incorrect estimation ---
fig, ax = plt.subplots()
fig.set_size_inches(10, 6)
width = 0.35
pos = np.arange(len(true_labels))
p1 = plt.bar(pos, estimated_correct_labels, width, color='g', label='Correct estimated')
p2 = plt.bar(pos + width, np.abs(estimated_labels - estimated_correct_labels), width, color='b', label='Incorrect estimated')
ax.set_xticks(pos + width / 2)
ax.set_xticklabels(test_env.attack_types, rotation='vertical', fontsize='large')
plt.legend(fontsize='large')
plt.tight_layout()
plt.savefig('results/test_adv_summary.png', dpi=300)
plt.show()

print("\nEvaluation complete! Check results/ for visualizations.")
# Out:
# Test set shape: (22544, 122), labels shape: (22544, 40)
# Attack types: ['normal', 'DoS', 'Probe', 'R2L', 'U2R']
# Sample mapped indices (true): [1 3 0 2 1 0 2 1 3 1]
# Sample predictions: [[1]
#  [3]
#  [0]
#  [3]
#  [4]
#  [0]
#  [2]
#  [1]
#  [1]
#  [1]]
#
# Confusion matrix (counts):
# [[7878  389  917  335  192]
#  [ 665 5518  436  715  124]
#  [  39  179 2036  136   31]
#  [ 983   89  169 1195  318]
#  [  30    6   75   28   61]]
# Classification report:
#                precision    recall  f1-score   support
#
#       normal     0.8211    0.8112    0.8161      9711
#          DoS     0.8927    0.7399    0.8092      7458
#        Probe     0.5604    0.8410    0.6726      2421
#          R2L     0.4961    0.4339    0.4629      2754
#          U2R     0.0840    0.3050    0.1317       200
#
#     accuracy                         0.7402     22544
#    macro avg     0.5709    0.6262    0.5785     22544
# weighted avg     0.7705    0.7402    0.7492     22544
#
#
# Custom per-class summary:
#        Estimated Correct Total   F1_score
# normal      9595    7878  9711  81.611934
# DoS         6181    5518  7458  80.915023
# Probe       3633    2036  2421  67.261315
# R2L         2409    1195  2754  46.290916
# U2R          726      61   200  13.174946
#
# Performance on test data:
# Accuracy = 0.7402
# F1 = 0.7492
# Precision = 0.7705
# Recall = 0.7402
# Evaluation complete! Check results/ for visualizations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score, precision_score, recall_score

# ========== TEST/EVALUATION BLOCK ==========

# --- Prepare test environment and reload agent ---
test_env = RLenv('test', train_path=kdd_train, test_path=kdd_test,
                 formated_train_path=formated_train_path, formated_test_path=formated_test_path,
                 batch_size=1, iterations_episode=1)  # batch_size=1 for prediction
test_obs_size = test_env.X.shape[1]
test_defender_agent = Agent(defender_valid_actions, test_obs_size, gamma=0.99, hidden_size=128, hidden_layers=3)
test_defender_agent.load("models/defender")

# --- Load test data ---
states, labels = test_env.get_full()
print(f"Test set shape: {states.shape}, labels shape: {labels.shape}")

# --- Predict with defender agent ---
preds = []
for i in range(len(states)):
    action, *_ = test_defender_agent.act(states[i])
    preds.append(action)
preds = np.array(preds)

# --- Map true labels (one-hot) to attack_type indices ---
maped = []
for i in range(len(labels)):
    attack_name = test_env.attack_names[np.argmax(labels[i])]
    maped.append(test_env.attack_types.index(test_env.attack_map[attack_name]))
maped = np.array(maped)

# --- Sanity Checks ---
print("Attack types:", test_env.attack_types)
print("Sample mapped indices (true):", maped[:10])
print("Sample predictions:", preds[:10])

# --- Confusion Matrix and Per-Class Metrics ---
cm = confusion_matrix(maped, preds)
print("\nConfusion matrix (counts):")
print(cm)

# --- Normalize by true labels (rows) ---
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cm_normalized = np.nan_to_num(cm_normalized)

# --- Plot normalized confusion matrix ---
plt.figure(figsize=(8, 6))
plt.imshow(cm_normalized, interpolation='nearest', cmap=plt.cm.Blues)
plt.title("Normalized Confusion Matrix")
plt.colorbar(label='Fraction of True Labels')
tick_marks = np.arange(len(test_env.attack_types))
plt.xticks(tick_marks, test_env.attack_types, rotation=45)
plt.yticks(tick_marks, test_env.attack_types)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
for i in range(cm_normalized.shape[0]):
    for j in range(cm_normalized.shape[1]):
        plt.text(j, i, f"{cm_normalized[i, j]:.2f}",
                 ha="center", va="center",
                 color="white" if cm_normalized[i, j] > 0.5 else "black")
plt.tight_layout()
os.makedirs('results', exist_ok=True)
plt.savefig('results/normalized_confusion_matrix.png', dpi=300)
plt.show()

# --- Per-class report ---
report = classification_report(maped, preds, target_names=test_env.attack_types, digits=4)
print("\nClassification report:\n", report)

# --- Per-class F1 and custom table ---
true_labels = np.bincount(maped, minlength=len(test_env.attack_types))
preds = np.asarray(preds).astype(int).flatten()
estimated_labels = np.bincount(preds, minlength=len(test_env.attack_types))
estimated_correct_labels = np.zeros(len(test_env.attack_types), dtype=int)
for idx, a in enumerate(preds):
    if a == maped[idx]:
        estimated_correct_labels[a] += 1
outputs_df = pd.DataFrame(index=test_env.attack_types, columns=["Estimated", "Correct", "Total", "F1_score"])
for idx, att in enumerate(test_env.attack_types):
    f1 = f1_score(maped == idx, preds == idx)
    outputs_df.loc[att] = [
        estimated_labels[idx], estimated_correct_labels[idx], true_labels[idx], f1 * 100
    ]
print("\nCustom per-class summary:")
print(outputs_df)

# --- Overall metrics ---
print('\nPerformance on test data:')
print('Accuracy = {:.4f}'.format(accuracy_score(maped, preds)))
print('F1 = {:.4f}'.format(f1_score(maped, preds, average="weighted")))
print('Precision = {:.4f}'.format(precision_score(maped, preds, average="weighted")))
print('Recall = {:.4f}'.format(recall_score(maped, preds, average="weighted")))

# --- Bar chart for correct/incorrect estimation ---
fig, ax = plt.subplots()
fig.set_size_inches(10, 6)
width = 0.35
pos = np.arange(len(true_labels))
p1 = plt.bar(pos, estimated_correct_labels, width, color='g', label='Correct estimated')
p2 = plt.bar(pos + width, np.abs(estimated_labels - estimated_correct_labels), width, color='b', label='Incorrect estimated')
ax.set_xticks(pos + width / 2)
ax.set_xticklabels(test_env.attack_types, rotation='vertical', fontsize='large')
plt.legend(fontsize='large')
plt.tight_layout()
plt.savefig('results/test_adv_summary.png', dpi=300)
plt.show()

print("\nEvaluation complete! Check results/ for visualizations.")

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 6)
width = 0.35
pos = np.arange(len(true_labels))
p1 = plt.bar(pos, estimated_correct_labels,width,color='g')
p1 = plt.bar(pos+width,
             (np.abs(estimated_correct_labels-true_labels)),width,
             color='r')
p2 = plt.bar(pos+width,np.abs(estimated_labels-estimated_correct_labels),width,
             bottom=(np.abs(estimated_correct_labels-true_labels)),
             color='b')

ax.yaxis.set_tick_params(labelsize=15)
ax.set_xticks(pos+width/2)
ax.set_xticklabels(env.attack_types,rotation='vertical',fontsize = 'xx-large')

#ax.set_yscale('log')

#ax.set_ylim([0, 100])
#ax.set_title('Test set scores',fontsize = 'xx-large')
#ax.set_title('Test set scores, Acc = {:.2f}'.format(acc))
plt.legend(('Correct estimated','False negative','False positive'),fontsize = 'x-large')
plt.tight_layout()
#plt.show()
plt.savefig('results/test_adv_imp.svg', format='svg', dpi=1000)

# %% [markdown]
# xem cái gì bị sai ở u2l r2l vì ít thông tin xem có phải attack name khác k

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential, load_model
from keras.layers import Input, Dense
from keras import optimizers
import tensorflow as tf
import os
import time
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score, precision_score, recall_score

# =================== DATA LOADER ===================
class data_cls:
    def __init__(self, train_test, **kwargs):
        col_names = ["duration", "protocol_type", "service", "flag", "src_bytes",
                     "dst_bytes", "land_f", "wrong_fragment", "urgent", "hot",
                     "num_failed_logins", "logged_in", "num_compromised", "root_shell",
                     "su_attempted", "num_root", "num_file_creations", "num_shells",
                     "num_access_files", "num_outbound_cmds", "is_host_login",
                     "is_guest_login", "count", "srv_count", "serror_rate",
                     "srv_serror_rate", "rerror_rate", "srv_rerror_rate", "same_srv_rate",
                     "diff_srv_rate", "srv_diff_host_rate", "dst_host_count",
                     "dst_host_srv_count", "dst_host_same_srv_rate", "dst_host_diff_srv_rate",
                     "dst_host_same_src_port_rate", "dst_host_srv_diff_host_rate",
                     "dst_host_serror_rate", "dst_host_srv_serror_rate", "dst_host_rerror_rate",
                     "dst_host_srv_rerror_rate", "labels", "dificulty"]
        self.train_test = train_test
        self.train_path = kwargs.get('train_path', 'KDDTrain+.txt')
        self.test_path = kwargs.get('test_path', 'KDDTest+.txt')
        self.formated_train_path = kwargs.get('formated_train_path', "formated_train_adv.data")
        self.formated_test_path = kwargs.get('formated_test_path', "formated_test_adv.data")

        self.attack_types = ['normal', 'DoS', 'Probe', 'R2L', 'U2R']
        self.attack_map = {
            'normal': 'normal', 'back': 'DoS', 'land': 'DoS', 'neptune': 'DoS', 'pod': 'DoS', 'smurf': 'DoS',
            'teardrop': 'DoS', 'mailbomb': 'DoS', 'apache2': 'DoS', 'processtable': 'DoS', 'udpstorm': 'DoS',
            'ipsweep': 'Probe', 'nmap': 'Probe', 'portsweep': 'Probe', 'satan': 'Probe', 'mscan': 'Probe',
            'saint': 'Probe', 'ftp_write': 'R2L', 'guess_passwd': 'R2L', 'imap': 'R2L', 'multihop': 'R2L',
            'phf': 'R2L', 'spy': 'R2L', 'warezclient': 'R2L', 'warezmaster': 'R2L', 'sendmail': 'R2L',
            'named': 'R2L', 'snmpgetattack': 'R2L', 'snmpguess': 'R2L', 'xlock': 'R2L', 'xsnoop': 'R2L',
            'worm': 'R2L', 'buffer_overflow': 'U2R', 'loadmodule': 'U2R', 'perl': 'U2R', 'rootkit': 'U2R',
            'httptunnel': 'U2R', 'ps': 'U2R', 'sqlattack': 'U2R', 'xterm': 'U2R'
        }
        self.all_attack_names = list(self.attack_map.keys())
        self.attack_names = []
        self._prepare_data(col_names)

    def _prepare_data(self, col_names):
        if os.path.exists(self.formated_train_path) and os.path.exists(self.formated_test_path):
            df_train = pd.read_csv(self.formated_train_path, sep=',')
            df_test = pd.read_csv(self.formated_test_path, sep=',')
        else:
            df_train = pd.read_csv(self.train_path, sep=',', names=col_names, index_col=False)
            df_test = pd.read_csv(self.test_path, sep=',', names=col_names, index_col=False)
            if 'dificulty' in df_train.columns:
                df_train.drop('dificulty', axis=1, inplace=True)
            if 'dificulty' in df_test.columns:
                df_test.drop('dificulty', axis=1, inplace=True)
            full_df = pd.concat([df_train, df_test], ignore_index=True)
            for cat in ['protocol_type', 'service', 'flag']:
                full_df = pd.concat([full_df.drop(cat, axis=1), pd.get_dummies(full_df[cat])], axis=1)
            if 'su_attempted' in full_df.columns:
                full_df['su_attempted'] = full_df['su_attempted'].replace(2.0, 0.0)
            full_df = pd.concat([full_df.drop('labels', axis=1), pd.get_dummies(full_df['labels'])], axis=1)
            for col, dtype in full_df.dtypes.items():
                if dtype in ['float64', 'int64']:
                    if full_df[col].max() != full_df[col].min():
                        full_df[col] = (full_df[col] - full_df[col].min()) / (full_df[col] - full_df[col].min())
                    else:
                        full_df[col] = 0
            df_train = full_df.iloc[:len(df_train)]
            df_test = full_df.iloc[len(df_train):]
            df_train.to_csv(self.formated_train_path, sep=',', index=False)
            df_test.to_csv(self.formated_test_path, sep=',', index=False)

        for att in self.attack_map:
            if ((att in df_train.columns and np.sum(df_train[att].values) > 1) or
                (att in df_test.columns and np.sum(df_test[att].values) > 1)):
                self.attack_names.append(att)

        feature_cols = [c for c in df_train.columns if c not in self.all_attack_names]
        label_cols = self.attack_names

        if self.train_test == 'train':
            self.X = df_train[feature_cols].values.astype(np.float32)
            self.y = df_train[label_cols].values.astype(np.float32)
        else:
            self.X = df_test[feature_cols].values.astype(np.float32)
            self.y = df_test[label_cols].values.astype(np.float32)

        idx = np.random.permutation(len(self.X))
        self.X, self.y = self.X[idx], self.y[idx]

    def get_shape(self):
        return self.X.shape

    def get_full(self):
        return self.X, self.y

# =================== NETWORKS ===================
class PolicyNetwork:
    def __init__(self, obs_size, num_actions, hidden_size=128, hidden_layers=1):
        self.model = Sequential()
        self.model.add(Input(shape=(obs_size,)))
        self.model.add(Dense(hidden_size, activation='relu'))
        for _ in range(hidden_layers):
            self.model.add(Dense(hidden_size, activation='relu'))
        self.model.add(Dense(num_actions, activation='softmax'))
        self.optimizer = optimizers.Adam(learning_rate=0.0001)

class ValueNetwork:
    def __init__(self, obs_size, hidden_size=128, hidden_layers=1):
        self.model = Sequential()
        self.model.add(Input(shape=(obs_size,)))
        self.model.add(Dense(hidden_size, activation='relu'))
        for _ in range(hidden_layers):
            self.model.add(Dense(hidden_size, activation='relu'))
        self.model.add(Dense(1, activation='linear'))
        self.optimizer = optimizers.Adam(learning_rate=0.0001)

# =================== AGENTS ===================
class Agent:
    def __init__(self, actions, obs_size, **kwargs):
        self.actions = actions
        self.num_actions = len(actions)
        self.obs_size = obs_size
        self.gamma = kwargs.get('gamma', 0.99)
        self.lam = kwargs.get('lam', 0.95)
        self.clip_epsilon = kwargs.get('clip_epsilon', 0.1)
        self.policy_net = PolicyNetwork(obs_size, self.num_actions, kwargs.get('hidden_size', 128), kwargs.get('hidden_layers', 1))
        self.value_net = ValueNetwork(obs_size, kwargs.get('hidden_size', 128), kwargs.get('hidden_layers', 1))
        self.action_counts = np.zeros(self.num_actions)

    def act(self, states):
        if states.ndim == 1:
            states = states.reshape(1, -1)
        batch_size = states.shape[0]
        probs = self.policy_net.model(states, training=False).numpy()
        values = self.value_net.model(states, training=False).numpy().flatten()
        actions = np.array([np.random.choice(self.num_actions, p=probs[i]) for i in range(batch_size)])
        log_probs = np.array([np.log(probs[i, actions[i]] + 1e-8) for i in range(batch_size)])
        entropies = np.array([-np.sum(probs[i] * np.log(probs[i] + 1e-8)) for i in range(batch_size)])
        for a in actions:
            self.action_counts[a] += 1
        return actions, log_probs, values, entropies

    def compute_gae(self, rewards, values, next_value):
        rewards = np.vstack(rewards)
        values = np.vstack(values)
        next_value = np.array(next_value)
        batch_size = rewards.shape[1]
        advantages = np.zeros_like(rewards, dtype=np.float32)
        returns = np.zeros_like(rewards, dtype=np.float32)

        for b in range(batch_size):
            traj_rewards = rewards[:, b]
            traj_values = values[:, b]
            traj_next_value = next_value[b]
            traj_next_values = np.append(traj_values[1:], traj_next_value)
            deltas = traj_rewards + self.gamma * traj_next_values - traj_values
            adv = 0
            adv_list = []
            for delta in deltas[::-1]:
                adv = delta + self.gamma * self.lam * adv
                adv_list.insert(0, adv)
            traj_advantages = np.array(adv_list)
            traj_returns = traj_advantages + traj_values
            traj_advantages = (traj_advantages - np.mean(traj_advantages)) / (np.std(traj_advantages) + 1e-8)
            advantages[:, b] = traj_advantages
            returns[:, b] = traj_returns
        return advantages, returns

    # ...existing code...
    def ppo_update(self, states, actions, log_probs_old, advantages, returns, epochs=10, minibatch_size=32, entropy_coef=0.05):
        states = np.vstack(states)
        actions = np.hstack(actions)
        log_probs_old = np.hstack(log_probs_old)
        advantages = advantages.flatten()
        returns = returns.flatten()
        
        policy_losses, value_losses, grad_norms = [], [], []

        for _ in range(epochs):
            indices = np.random.permutation(len(states))
            for start in range(0, len(states), minibatch_size):
                batch_indices = indices[start:start + minibatch_size]
                batch_states = states[batch_indices]
                batch_actions = actions[batch_indices]
                batch_log_probs_old = log_probs_old[batch_indices]
                batch_advantages = advantages[batch_indices]
                batch_returns = returns[batch_indices]
                with tf.GradientTape() as tape:
                    probs = self.policy_net.model(batch_states, training=True)
                    log_probs_new = tf.math.log(tf.gather(probs, batch_actions, batch_dims=1) + 1e-8)
                    values_new = self.value_net.model(batch_states, training=True)
                    ratio = tf.exp(log_probs_new - batch_log_probs_old)
                    sur1 = ratio * batch_advantages
                    sur2 = tf.clip_by_value(ratio, 1 - self.clip_epsilon, 1 + self.clip_epsilon) * batch_advantages
                    # Entropy bonus
                    entropy = -tf.reduce_mean(tf.reduce_sum(probs * tf.math.log(probs + 1e-8), axis=1))
                    policy_loss = -tf.reduce_mean(tf.minimum(sur1, sur2)) - entropy_coef * entropy
                    value_loss = tf.reduce_mean(tf.square(batch_returns - values_new))
                    loss = policy_loss + 0.5 * value_loss
                policy_losses.append(policy_loss.numpy())
                value_losses.append(value_loss.numpy())
                variables = self.policy_net.model.trainable_variables + self.value_net.model.trainable_variables
                grads = tape.gradient(loss, variables)
                grad_norm = tf.sqrt(tf.reduce_sum([tf.reduce_sum(tf.square(g)) for g in grads if g is not None]))
                grad_norms.append(grad_norm.numpy())
                self.policy_net.optimizer.apply_gradients(zip(grads[:len(self.policy_net.model.trainable_variables)], self.policy_net.model.trainable_variables))
                self.value_net.optimizer.apply_gradients(zip(grads[len(self.policy_net.model.trainable_variables):], self.value_net.model.trainable_variables))
        return np.mean(policy_losses), np.mean(value_losses), np.mean(grad_norms)

    def get_action_distribution(self):
        total = np.sum(self.action_counts)
        if total == 0:
            return np.zeros(self.num_actions)
        return self.action_counts / total

    def reset_action_counts(self):
        self.action_counts = np.zeros(self.num_actions)
        
    def save(self, prefix):
        self.policy_net.model.save(f"{prefix}_policy.keras")
        self.value_net.model.save(f"{prefix}_value.keras")

    def load(self, prefix):
        self.policy_net.model = load_model(f"{prefix}_policy.keras")
        self.value_net.model = load_model(f"{prefix}_value.keras")

# =================== RL ENVIRONMENT ===================
class RLenv(data_cls):
    def __init__(self, train_test, **kwargs):
        super().__init__(train_test, **kwargs)
        self.data_shape = self.get_shape()
        self.batch_size = kwargs.get('batch_size', 1)
        self.iterations_episode = kwargs.get('iterations_episode', 100)

    def reset(self):
        self.def_true_labels = np.zeros(len(self.attack_types), dtype=int)
        self.def_estimated_labels = np.zeros(len(self.attack_types), dtype=int)
        self.att_true_labels = np.zeros(len(self.attack_names), dtype=int)
        self.def_correct = np.zeros(len(self.attack_types), dtype=int)
        self.def_incorrect = np.zeros(len(self.attack_types), dtype=int)
        self.confusion_matrix = np.zeros((len(self.attack_types), len(self.attack_types)), dtype=int)
        idx = np.random.choice(len(self.X), self.batch_size, replace=False)
        self.states = self.X[idx]
        self.labels = self.y[idx]
        return self.states

    def act(self, defender_actions, attack_actions):
        self.def_reward = np.zeros(len(defender_actions))
        self.att_reward = np.zeros(len(attack_actions))
        for i in range(len(defender_actions)):
            def_action = defender_actions[i]
            true_attack = np.argmax(self.labels[i])
            true_class = self.attack_types.index(self.attack_map[self.attack_names[true_attack]])
            est_class = def_action
            attack_type_name = self.attack_types[true_class]

            # Update classification stats
            self.def_true_labels[true_class] += 1
            self.def_estimated_labels[est_class] += 1
            self.att_true_labels[attack_actions[i]] += 1
            self.confusion_matrix[true_class, est_class] += 1
            
            if est_class == true_class:
                self.def_correct[true_class] += 1
            else:
                self.def_incorrect[true_class] += 1

            # DEFENDER REWARD
            if def_action == true_class:
                if attack_type_name in ['U2R', 'R2L']:
                    self.def_reward[i] = 2.0  # rare attack correctly identified
                elif attack_type_name in ['DoS', 'Probe']:
                    self.def_reward[i] = 1.0  # common attack correctly identified
                else:
                    self.def_reward[i] = 0.5  # normal
            else:
                self.def_reward[i] = -0.5  # misclassification

            # ATTACKER REWARD
            if def_action != true_class:
                if attack_type_name in ['U2R', 'R2L']:
                    self.att_reward[i] = 2.0  # rare attack evaded detection
                elif attack_type_name in ['DoS', 'Probe']:
                    self.att_reward[i] = 1.0  # common attack evaded detection
                else:
                    self.att_reward[i] = 0.5  # 'normal' shouldn't be rewarded
            else:
                self.att_reward[i] = -0.5  # attacker failed

        return self.states, self.def_reward, self.att_reward, False

    def get_states(self, attacker_actions):
        idxs = []
        for att_action in attacker_actions:
            att_name = self.attack_names[att_action]  # Get name like 'neptune', 'normal', etc.
            att_idx = self.attack_names.index(att_name)
            # Find all indices where this attack is present in the one-hot label vector
            attack_indices = np.where(self.y[:, att_idx] == 1)[0]
            if len(attack_indices) > 0:
                sampled_idx = np.random.choice(attack_indices, size=1)[0]
                idxs.append(sampled_idx)
            else:
                # Fallback: sample a random index if no matching data found (should rarely happen)
                idxs.append(np.random.choice(len(self.X), size=1)[0])

        # Now batch is 1-to-1 matched to attacker actions
        idxs = np.array(idxs)
        minibatch = self.X[idxs]
        self.labels = self.y[idxs]
        self.states = minibatch
        return self.states


# =================== MAIN TRAINING LOOP ===================
if __name__ == "__main__":
    # ==== Paths ====
    kdd_train = "https://raw.githubusercontent.com/gcamfer/Anomaly-ReactionRL/master/datasets/NSL/KDDTrain%2B.txt"
    kdd_test = "https://raw.githubusercontent.com/gcamfer/Anomaly-ReactionRL/master/datasets/NSL/KDDTest%2B.txt"
    formated_train_path = "formated_train_adv.data"
    formated_test_path = "formated_test_adv.data"

    batch_size = 32
    iterations_episode = 50
    num_episodes = 100

    env = RLenv('train', train_path=kdd_train, test_path=kdd_test,
                formated_train_path=formated_train_path, formated_test_path=formated_test_path,
                batch_size=batch_size, iterations_episode=iterations_episode)
    obs_size = env.X.shape[1]

    defender_valid_actions = list(range(len(env.attack_types)))
    defender_num_actions = len(defender_valid_actions)
    defender_agent = Agent(defender_valid_actions, obs_size, gamma=0.99, hidden_size=128, hidden_layers=3)
    attack_valid_actions = list(range(len(env.attack_names)))
    attack_num_actions = len(attack_valid_actions)
    attacker_agent = Agent(attack_valid_actions, obs_size, gamma=0.99, hidden_size=128, hidden_layers=1)

    att_reward_chain, def_reward_chain = [], []
    def_loss_chain = []  # fill this during training with `def_value_loss` per epoch
    att_loss_chain = []  # fill this during training with `att_value_loss` per epoch

    attacks_by_epoch = []
    print("-------------------------------------------------------------------------------")
    print(f"Total epochs: {num_episodes} | Steps per epoch: {iterations_episode} | Batch size: {batch_size}")
    print("-------------------------------------------------------------------------------")
    print(f"Dataset shape: {env.data_shape}")
    print("-------------------------------------------------------------------------------")

    for epoch in range(num_episodes):
        def_total_reward, att_total_reward = 0, 0
        defender_agent.reset_action_counts()
        attacker_agent.reset_action_counts()

        states = env.reset()
        att_actions, att_log_probs, att_values, att_entropies = attacker_agent.act(states)
        states = env.get_states(att_actions)
        att_actions_this_epoch = [att_actions]

        states_list = [states]
        att_actions_list, att_log_probs_list, att_values_list, att_rewards_list = [att_actions], [att_log_probs], [att_values], []
        def_actions_list, def_log_probs_list, def_values_list, def_rewards_list = [], [], [], []

        epoch_def_entropies, epoch_att_entropies = [], []

        start_time = time.time()

        for t in range(iterations_episode):
            def_actions, def_log_probs, def_values, def_entropies = defender_agent.act(states)
            def_actions_list.append(def_actions)
            def_log_probs_list.append(def_log_probs)
            def_values_list.append(def_values)
            epoch_def_entropies.append(np.mean(def_entropies))

            next_states, def_rewards, att_rewards, _ = env.act(def_actions, att_actions)
            def_rewards_list.append(def_rewards)
            att_rewards_list.append(att_rewards)
            def_total_reward += np.sum(def_rewards)
            att_total_reward += np.sum(att_rewards)

            next_att_actions, next_att_log_probs, next_att_values, next_att_entropies = attacker_agent.act(states)
            att_actions_list.append(next_att_actions)
            att_log_probs_list.append(next_att_log_probs)
            att_values_list.append(next_att_values)
            att_actions_this_epoch.append(next_att_actions)
            epoch_att_entropies.append(np.mean(next_att_entropies))

            states = env.get_states(next_att_actions)
            states_list.append(states)
            att_actions = next_att_actions

        # PPO update
        att_next_value = attacker_agent.value_net.model.predict(states, verbose=0).flatten()
        att_advantages, att_returns = attacker_agent.compute_gae(att_rewards_list, att_values_list[:-1], att_next_value)
        def_next_value = defender_agent.value_net.model.predict(states, verbose=0).flatten()
        def_advantages, def_returns = defender_agent.compute_gae(def_rewards_list, def_values_list, def_next_value)

        att_policy_loss, att_value_loss, att_grad_norm = attacker_agent.ppo_update(
            states_list[:-1], att_actions_list[:-1], att_log_probs_list[:-1], att_advantages, att_returns, entropy_coef=0.01
        )
        def_policy_loss, def_value_loss, def_grad_norm = defender_agent.ppo_update(
            states_list[:-1], def_actions_list, def_log_probs_list, def_advantages, def_returns
        )

        def_reward_chain.append(def_total_reward)
        att_reward_chain.append(att_total_reward)
        def_loss_chain.append(def_value_loss)
        att_loss_chain.append(att_value_loss)

        attacks_by_epoch.append(np.vstack(att_actions_this_epoch))

        end_time = time.time()

        # Compute per-class accuracy
        class_accuracies = []
        for i, attack_type in enumerate(env.attack_types):
            total = env.def_correct[i] + env.def_incorrect[i]
            accuracy = (env.def_correct[i] / total * 100) if total > 0 else 0
            class_accuracies.append(accuracy)
        class_accuracies_str = [f"{attack_type}: {acc:.1f}%" for attack_type, acc in zip(env.attack_types, class_accuracies)]

        # Early stopping based on attack class accuracies (excluding normal)
        attack_accuracies = class_accuracies[1:]  # Exclude normal (index 0)
        avg_attack_accuracy = np.mean(attack_accuracies)
        print(f"Epoch {epoch}, Average Attack Accuracy: {avg_attack_accuracy:.2f}%")
        if avg_attack_accuracy > 98:  # Stop if average attack accuracy exceeds 90%
            print(f"Early stopping at epoch {epoch}: Average attack accuracy {avg_attack_accuracy:.2f}%")
            break

        print(
            f"\n|Epoch {epoch:03d}/{num_episodes:03d}| Time: {end_time - start_time:.2f}|"
            f"\n|Def Reward: {def_total_reward:03.0f}| Att Reward: {att_total_reward:03.0f}|"
            f"\n|Def Estimated: {np.array2string(env.def_estimated_labels, separator=' ')}| Att Labels: {np.array2string(env.def_true_labels, separator=' ')}"
            f"\n|Def Policy Loss: {def_policy_loss:.4f}| Def Value Loss: {def_value_loss:.4f}| Def Grad Norm: {def_grad_norm:.4f}|"
            f"\n|Att Policy Loss: {att_policy_loss:.4f}| Att Value Loss: {att_value_loss:.4f}| Att Grad Norm: {att_grad_norm:.4f}|"
            f"\n|Def Correct: {np.array2string(env.def_correct, separator=' ')} ({env.attack_types})|"
            f"\n|Def Incorrect: {np.array2string(env.def_incorrect, separator=' ')} ({env.attack_types})|"
            f"\n|Class Accuracies: {', '.join(class_accuracies_str)}|"
            f"\n|Def Entropy: {np.mean(epoch_def_entropies):.4f}| Att Entropy: {np.mean(epoch_att_entropies):.4f}|"
        )

    # ============== VISUALIZE ATTACKER CLASS DISTRIBUTION ==========
    epochs_to_plot = list(range(0, len(attacks_by_epoch), 10))
    class_names = env.attack_types
    attack_counts_per_epoch = []
    for e in epochs_to_plot:
        sample = attacks_by_epoch[e]
        sample_mapped = [env.attack_types.index(env.attack_map[env.attack_names[att]]) for att in sample.flatten()]
        counts = [sample_mapped.count(i) for i in range(len(class_names))]
        attack_counts_per_epoch.append(counts)
    attack_counts_per_epoch = np.array(attack_counts_per_epoch)
    bar_width = 0.15
    x = np.arange(len(epochs_to_plot))
    plt.figure(figsize=(12, 6))
    for i, cname in enumerate(class_names):
        plt.bar(x + i*bar_width, attack_counts_per_epoch[:, i], width=bar_width, label=cname)
    plt.xlabel("Epoch")
    plt.ylabel("Number of samples")
    plt.title("Attacker Class Distribution Across Epochs")
    plt.xticks(x + bar_width*2, epochs_to_plot)
    plt.legend()
    plt.tight_layout()
    os.makedirs('results', exist_ok=True)
    plt.savefig("results/attacker_distribution.png", dpi=300)
    plt.show()
    
    os.makedirs('models', exist_ok=True)
    defender_agent.save("models/defender")
    attacker_agent.save("models/attacker")

    print("Training and visualization done. Proceed to evaluation/test as next step.")
# Out:
# -------------------------------------------------------------------------------
# Total epochs: 100 | Steps per epoch: 50 | Batch size: 32
# -------------------------------------------------------------------------------
# Dataset shape: (125973, 122)
# -------------------------------------------------------------------------------
# WARNING:tensorflow:5 out of the last 159 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x355b87100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 0, Average Attack Accuracy: 19.55%
#
# |Epoch 000/100| Time: 32.13|
# |Def Reward: -288| Att Reward: 1350|
# |Def Estimated: [315 301 343 316 325]| Att Labels: [401 496 241 304 158]
# |Def Policy Loss: -0.0363| Def Value Loss: 4.3403| Def Grad Norm: 1.9244|
# |Att Policy Loss: -0.0415| Att Value Loss: 39.7104| Att Grad Norm: 17.8998|
# |Def Correct: [75 92 49 58 32] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [326 404 192 246 126] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 18.7%, DoS: 18.5%, Probe: 20.3%, R2L: 19.1%, U2R: 20.3%|
# |Def Entropy: 1.6082| Att Entropy: 3.6785|
# Epoch 1, Average Attack Accuracy: 20.28%
#
# |Epoch 001/100| Time: 30.69|
# |Def Reward: -252| Att Reward: 1328|
# |Def Estimated: [323 329 325 308 315]| Att Labels: [404 505 213 321 157]
# |Def Policy Loss: -0.0404| Def Value Loss: 4.1452| Def Grad Norm: 2.8137|
# |Att Policy Loss: -0.0451| Att Value Loss: 20.9381| Att Grad Norm: 16.4790|
# |Def Correct: [ 96 109  51  57  28] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [308 396 162 264 129] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 23.8%, DoS: 21.6%, Probe: 23.9%, R2L: 17.8%, U2R: 17.8%|
# |Def Entropy: 1.6065| Att Entropy: 3.6801|
# Epoch 2, Average Attack Accuracy: 23.67%
#
# |Epoch 002/100| Time: 30.39|
# |Def Reward: -166| Att Reward: 1235|
# |Def Estimated: [322 313 316 356 293]| Att Labels: [376 502 265 319 138]
# |Def Policy Loss: -0.0441| Def Value Loss: 3.5791| Def Grad Norm: 3.0522|
# |Att Policy Loss: -0.0456| Att Value Loss: 13.6420| Att Grad Norm: 16.6085|
# |Def Correct: [ 91 105  67  83  31] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [285 397 198 236 107] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 24.2%, DoS: 20.9%, Probe: 25.3%, R2L: 26.0%, U2R: 22.5%|
# |Def Entropy: 1.5981| Att Entropy: 3.6801|
# Epoch 3, Average Attack Accuracy: 29.09%
#
# |Epoch 003/100| Time: 30.39|
# |Def Reward: -08| Att Reward: 1104|
# |Def Estimated: [280 351 323 356 290]| Att Labels: [395 471 240 338 156]
# |Def Policy Loss: -0.0446| Def Value Loss: 4.7040| Def Grad Norm: 2.9611|
# |Att Policy Loss: -0.0470| Att Value Loss: 12.2355| Att Grad Norm: 16.8810|
# |Def Correct: [106 145  74 107  36] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [289 326 166 231 120] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 26.8%, DoS: 30.8%, Probe: 30.8%, R2L: 31.7%, U2R: 23.1%|
# |Def Entropy: 1.5848| Att Entropy: 3.6782|
# Epoch 4, Average Attack Accuracy: 28.65%
#
# |Epoch 004/100| Time: 30.33|
# |Def Reward: -20| Att Reward: 1120|
# |Def Estimated: [308 330 293 366 303]| Att Labels: [380 475 255 337 153]
# |Def Policy Loss: -0.0427| Def Value Loss: 5.3931| Def Grad Norm: 2.9686|
# |Att Policy Loss: -0.0436| Att Value Loss: 10.4625| Att Grad Norm: 17.1264|
# |Def Correct: [ 97 140  72 108  38] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [283 335 183 229 115] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 25.5%, DoS: 29.5%, Probe: 28.2%, R2L: 32.0%, U2R: 24.8%|
# |Def Entropy: 1.5656| Att Entropy: 3.6778|
# Epoch 5, Average Attack Accuracy: 34.61%
#
# |Epoch 005/100| Time: 30.35|
# |Def Reward: 152| Att Reward: 980|
# |Def Estimated: [303 367 304 362 264]| Att Labels: [369 478 237 359 157]
# |Def Policy Loss: -0.0461| Def Value Loss: 6.4039| Def Grad Norm: 2.2761|
# |Att Policy Loss: -0.0477| Att Value Loss: 9.1647| Att Grad Norm: 16.0134|
# |Def Correct: [117 164  74 136  55] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [252 314 163 223 102] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 31.7%, DoS: 34.3%, Probe: 31.2%, R2L: 37.9%, U2R: 35.0%|
# |Def Entropy: 1.5375| Att Entropy: 3.6767|
# Epoch 6, Average Attack Accuracy: 36.00%
#
# |Epoch 006/100| Time: 30.48|
# |Def Reward: 198| Att Reward: 946|
# |Def Estimated: [307 377 254 362 300]| Att Labels: [367 475 231 358 169]
# |Def Policy Loss: -0.0442| Def Value Loss: 5.5673| Def Grad Norm: 1.5044|
# |Att Policy Loss: -0.0410| Att Value Loss: 6.6920| Att Grad Norm: 14.5679|
# |Def Correct: [114 166  80 152  54] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [253 309 151 206 115] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 31.1%, DoS: 34.9%, Probe: 34.6%, R2L: 42.5%, U2R: 32.0%|
# |Def Entropy: 1.5049| Att Entropy: 3.6736|
# Epoch 7, Average Attack Accuracy: 46.18%
#
# |Epoch 007/100| Time: 30.32|
# |Def Reward: 426| Att Reward: 733|
# |Def Estimated: [270 344 288 377 321]| Att Labels: [364 444 251 362 179]
# |Def Policy Loss: -0.0430| Def Value Loss: 8.7787| Def Grad Norm: 3.3481|
# |Att Policy Loss: -0.0418| Att Value Loss: 7.1603| Att Grad Norm: 13.7424|
# |Def Correct: [113 191 111 177  87] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [251 253 140 185  92] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 31.0%, DoS: 43.0%, Probe: 44.2%, R2L: 48.9%, U2R: 48.6%|
# |Def Entropy: 1.4671| Att Entropy: 3.6672|
# Epoch 8, Average Attack Accuracy: 44.03%
#
# |Epoch 008/100| Time: 30.77|
# |Def Reward: 436| Att Reward: 754|
# |Def Estimated: [273 367 252 404 304]| Att Labels: [340 436 265 366 193]
# |Def Policy Loss: -0.0412| Def Value Loss: 7.1373| Def Grad Norm: 5.0724|
# |Att Policy Loss: -0.0425| Att Value Loss: 6.5531| Att Grad Norm: 12.3777|
# |Def Correct: [113 190 105 196  76] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [227 246 160 170 117] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 33.2%, DoS: 43.6%, Probe: 39.6%, R2L: 53.6%, U2R: 39.4%|
# |Def Entropy: 1.4160| Att Entropy: 3.6636|
# Epoch 9, Average Attack Accuracy: 49.13%
#
# |Epoch 009/100| Time: 30.28|
# |Def Reward: 554| Att Reward: 642|
# |Def Estimated: [307 333 255 401 304]| Att Labels: [349 425 255 376 195]
# |Def Policy Loss: -0.0431| Def Value Loss: 8.0057| Def Grad Norm: 8.4784|
# |Att Policy Loss: -0.0439| Att Value Loss: 6.8888| Att Grad Norm: 14.0180|
# |Def Correct: [142 185 125 200  99] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [207 240 130 176  96] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 40.7%, DoS: 43.5%, Probe: 49.0%, R2L: 53.2%, U2R: 50.8%|
# |Def Entropy: 1.3704| Att Entropy: 3.6579|
# Epoch 10, Average Attack Accuracy: 49.71%
#
# |Epoch 010/100| Time: 30.20|
# |Def Reward: 632| Att Reward: 562|
# |Def Estimated: [297 371 222 442 268]| Att Labels: [341 452 243 385 179]
# |Def Policy Loss: -0.0383| Def Value Loss: 8.2001| Def Grad Norm: 11.9741|
# |Att Policy Loss: -0.0406| Att Value Loss: 6.8627| Att Grad Norm: 14.0046|
# |Def Correct: [156 213 109 235  82] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [185 239 134 150  97] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 45.7%, DoS: 47.1%, Probe: 44.9%, R2L: 61.0%, U2R: 45.8%|
# |Def Entropy: 1.3118| Att Entropy: 3.6519|
# Epoch 11, Average Attack Accuracy: 57.00%
#
# |Epoch 011/100| Time: 30.23|
# |Def Reward: 797| Att Reward: 412|
# |Def Estimated: [274 357 278 418 273]| Att Labels: [336 416 271 363 214]
# |Def Policy Loss: -0.0375| Def Value Loss: 9.3419| Def Grad Norm: 14.9106|
# |Att Policy Loss: -0.0400| Att Value Loss: 5.9309| Att Grad Norm: 13.5162|
# |Def Correct: [138 213 148 257 110] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [198 203 123 106 104] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 41.1%, DoS: 51.2%, Probe: 54.6%, R2L: 70.8%, U2R: 51.4%|
# |Def Entropy: 1.2453| Att Entropy: 3.6490|
# Epoch 12, Average Attack Accuracy: 62.30%
#
# |Epoch 012/100| Time: 30.36|
# |Def Reward: 928| Att Reward: 266|
# |Def Estimated: [271 356 287 428 258]| Att Labels: [331 439 270 357 203]
# |Def Policy Loss: -0.0315| Def Value Loss: 9.3564| Def Grad Norm: 19.1697|
# |Att Policy Loss: -0.0418| Att Value Loss: 5.7183| Att Grad Norm: 12.8657|
# |Def Correct: [156 238 172 270 113] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [175 201  98  87  90] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 47.1%, DoS: 54.2%, Probe: 63.7%, R2L: 75.6%, U2R: 55.7%|
# |Def Entropy: 1.1619| Att Entropy: 3.6455|
# Epoch 13, Average Attack Accuracy: 64.70%
#
# |Epoch 013/100| Time: 30.39|
# |Def Reward: 1028| Att Reward: 174|
# |Def Estimated: [270 368 238 472 252]| Att Labels: [348 427 249 366 210]
# |Def Policy Loss: -0.0302| Def Value Loss: 11.5834| Def Grad Norm: 24.6866|
# |Att Policy Loss: -0.0369| Att Value Loss: 7.0918| Att Grad Norm: 14.2226|
# |Def Correct: [166 258 145 302 121] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [182 169 104  64  89] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 47.7%, DoS: 60.4%, Probe: 58.2%, R2L: 82.5%, U2R: 57.6%|
# |Def Entropy: 1.0800| Att Entropy: 3.6453|
# Epoch 14, Average Attack Accuracy: 68.19%
#
# |Epoch 014/100| Time: 30.26|
# |Def Reward: 1136| Att Reward: 109|
# |Def Estimated: [254 352 254 439 301]| Att Labels: [299 440 267 358 236]
# |Def Policy Loss: -0.0262| Def Value Loss: 11.5984| Def Grad Norm: 31.4388|
# |Att Policy Loss: -0.0416| Att Value Loss: 6.7280| Att Grad Norm: 10.9891|
# |Def Correct: [151 265 168 296 158] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [148 175  99  62  78] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 50.5%, DoS: 60.2%, Probe: 62.9%, R2L: 82.7%, U2R: 66.9%|
# |Def Entropy: 1.0074| Att Entropy: 3.6453|
# Epoch 15, Average Attack Accuracy: 67.16%
#
# |Epoch 015/100| Time: 30.49|
# |Def Reward: 1080| Att Reward: 112|
# |Def Estimated: [263 359 256 469 253]| Att Labels: [342 418 276 363 201]
# |Def Policy Loss: -0.0265| Def Value Loss: 9.6013| Def Grad Norm: 30.6659|
# |Att Policy Loss: -0.0452| Att Value Loss: 6.7528| Att Grad Norm: 11.1592|
# |Def Correct: [175 256 166 298 131] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [167 162 110  65  70] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 51.2%, DoS: 61.2%, Probe: 60.1%, R2L: 82.1%, U2R: 65.2%|
# |Def Entropy: 0.9528| Att Entropy: 3.6440|
# Epoch 16, Average Attack Accuracy: 73.44%
#
# |Epoch 016/100| Time: 30.41|
# |Def Reward: 1257| Att Reward: -32|
# |Def Estimated: [256 351 254 492 247]| Att Labels: [332 432 245 373 218]
# |Def Policy Loss: -0.0230| Def Value Loss: 10.4420| Def Grad Norm: 35.6528|
# |Att Policy Loss: -0.0413| Att Value Loss: 5.6256| Att Grad Norm: 9.5886|
# |Def Correct: [170 270 173 334 155] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [162 162  72  39  63] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 51.2%, DoS: 62.5%, Probe: 70.6%, R2L: 89.5%, U2R: 71.1%|
# |Def Entropy: 0.8711| Att Entropy: 3.6454|
# Epoch 17, Average Attack Accuracy: 76.62%
#
# |Epoch 017/100| Time: 32.52|
# |Def Reward: 1351| Att Reward: -116|
# |Def Estimated: [267 359 242 460 272]| Att Labels: [335 425 238 376 226]
# |Def Policy Loss: -0.0225| Def Value Loss: 11.3996| Def Grad Norm: 40.7384|
# |Att Policy Loss: -0.0424| Att Value Loss: 6.7379| Att Grad Norm: 9.7688|
# |Def Correct: [180 276 168 340 182] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [155 149  70  36  44] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 53.7%, DoS: 64.9%, Probe: 70.6%, R2L: 90.4%, U2R: 80.5%|
# |Def Entropy: 0.8169| Att Entropy: 3.6464|
# Epoch 18, Average Attack Accuracy: 75.97%
#
# |Epoch 018/100| Time: 32.00|
# |Def Reward: 1332| Att Reward: -108|
# |Def Estimated: [240 371 245 476 268]| Att Labels: [317 436 265 361 221]
# |Def Policy Loss: -0.0198| Def Value Loss: 9.8488| Def Grad Norm: 41.8150|
# |Att Policy Loss: -0.0415| Att Value Loss: 5.6173| Att Grad Norm: 7.5699|
# |Def Correct: [164 300 177 333 168] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [153 136  88  28  53] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 51.7%, DoS: 68.8%, Probe: 66.8%, R2L: 92.2%, U2R: 76.0%|
# |Def Entropy: 0.7893| Att Entropy: 3.6473|
# Epoch 19, Average Attack Accuracy: 78.30%
#
# |Epoch 019/100| Time: 30.55|
# |Def Reward: 1361| Att Reward: -174|
# |Def Estimated: [279 390 251 431 249]| Att Labels: [327 468 254 340 211]
# |Def Policy Loss: -0.0210| Def Value Loss: 7.6389| Def Grad Norm: 43.7848|
# |Att Policy Loss: -0.0421| Att Value Loss: 5.4287| Att Grad Norm: 6.8115|
# |Def Correct: [193 334 183 313 164] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [134 134  71  27  47] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 59.0%, DoS: 71.4%, Probe: 72.0%, R2L: 92.1%, U2R: 77.7%|
# |Def Entropy: 0.7429| Att Entropy: 3.6476|
# Epoch 20, Average Attack Accuracy: 79.83%
#
# |Epoch 020/100| Time: 30.96|
# |Def Reward: 1382| Att Reward: -194|
# |Def Estimated: [249 367 289 450 245]| Att Labels: [319 441 292 343 205]
# |Def Policy Loss: -0.0180| Def Value Loss: 9.4542| Def Grad Norm: 49.1347|
# |Att Policy Loss: -0.0436| Att Value Loss: 5.4175| Att Grad Norm: 5.6029|
# |Def Correct: [174 301 218 324 168] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [145 140  74  19  37] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 54.5%, DoS: 68.3%, Probe: 74.7%, R2L: 94.5%, U2R: 82.0%|
# |Def Entropy: 0.7091| Att Entropy: 3.6468|
# Epoch 21, Average Attack Accuracy: 81.58%
#
# |Epoch 021/100| Time: 29.79|
# |Def Reward: 1453| Att Reward: -230|
# |Def Estimated: [238 382 260 428 292]| Att Labels: [329 405 278 321 267]
# |Def Policy Loss: -0.0165| Def Value Loss: 7.5252| Def Grad Norm: 42.9890|
# |Att Policy Loss: -0.0399| Att Value Loss: 4.4473| Att Grad Norm: 4.3036|
# |Def Correct: [183 310 210 302 214] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [146  95  68  19  53] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 55.6%, DoS: 76.5%, Probe: 75.5%, R2L: 94.1%, U2R: 80.1%|
# |Def Entropy: 0.6437| Att Entropy: 3.6436|
# Epoch 22, Average Attack Accuracy: 83.58%
#
# |Epoch 022/100| Time: 29.49|
# |Def Reward: 1481| Att Reward: -279|
# |Def Estimated: [257 357 279 431 276]| Att Labels: [342 409 276 335 238]
# |Def Policy Loss: -0.0146| Def Value Loss: 8.4147| Def Grad Norm: 51.2825|
# |Att Policy Loss: -0.0411| Att Value Loss: 4.0077| Att Grad Norm: 3.3023|
# |Def Correct: [190 304 220 321 201] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [152 105  56  14  37] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 55.6%, DoS: 74.3%, Probe: 79.7%, R2L: 95.8%, U2R: 84.5%|
# |Def Entropy: 0.5935| Att Entropy: 3.6459|
# Epoch 23, Average Attack Accuracy: 84.92%
#
# |Epoch 023/100| Time: 30.65|
# |Def Reward: 1530| Att Reward: -324|
# |Def Estimated: [232 385 263 436 284]| Att Labels: [335 416 275 342 232]
# |Def Policy Loss: -0.0154| Def Value Loss: 7.9922| Def Grad Norm: 53.6873|
# |Att Policy Loss: -0.0410| Att Value Loss: 4.0145| Att Grad Norm: 2.7285|
# |Def Correct: [191 324 212 328 206] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [144  92  63  14  26] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 57.0%, DoS: 77.9%, Probe: 77.1%, R2L: 95.9%, U2R: 88.8%|
# |Def Entropy: 0.5608| Att Entropy: 3.6478|
# Epoch 24, Average Attack Accuracy: 84.25%
#
# |Epoch 024/100| Time: 30.15|
# |Def Reward: 1502| Att Reward: -328|
# |Def Estimated: [269 402 234 446 249]| Att Labels: [359 441 247 342 211]
# |Def Policy Loss: -0.0153| Def Value Loss: 7.5064| Def Grad Norm: 49.3649|
# |Att Policy Loss: -0.0431| Att Value Loss: 4.0867| Att Grad Norm: 2.3142|
# |Def Correct: [223 352 192 330 175] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [136  89  55  12  36] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 62.1%, DoS: 79.8%, Probe: 77.7%, R2L: 96.5%, U2R: 82.9%|
# |Def Entropy: 0.5549| Att Entropy: 3.6483|
# Epoch 25, Average Attack Accuracy: 84.85%
#
# |Epoch 025/100| Time: 30.17|
# |Def Reward: 1508| Att Reward: -322|
# |Def Estimated: [250 395 263 449 243]| Att Labels: [330 440 278 358 194]
# |Def Policy Loss: -0.0141| Def Value Loss: 6.1029| Def Grad Norm: 48.0147|
# |Att Policy Loss: -0.0439| Att Value Loss: 4.2705| Att Grad Norm: 2.6034|
# |Def Correct: [196 344 226 336 167] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [134  96  52  22  27] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 59.4%, DoS: 78.2%, Probe: 81.3%, R2L: 93.9%, U2R: 86.1%|
# |Def Entropy: 0.5226| Att Entropy: 3.6452|
# Epoch 26, Average Attack Accuracy: 86.83%
#
# |Epoch 026/100| Time: 30.18|
# |Def Reward: 1554| Att Reward: -368|
# |Def Estimated: [228 420 259 420 273]| Att Labels: [330 453 266 333 218]
# |Def Policy Loss: -0.0147| Def Value Loss: 6.7398| Def Grad Norm: 52.3959|
# |Att Policy Loss: -0.0436| Att Value Loss: 3.3731| Att Grad Norm: 2.7900|
# |Def Correct: [190 371 215 323 191] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [140  82  51  10  27] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 57.6%, DoS: 81.9%, Probe: 80.8%, R2L: 97.0%, U2R: 87.6%|
# |Def Entropy: 0.4938| Att Entropy: 3.6468|
# Epoch 27, Average Attack Accuracy: 85.32%
#
# |Epoch 027/100| Time: 30.42|
# |Def Reward: 1512| Att Reward: -326|
# |Def Estimated: [235 387 280 447 251]| Att Labels: [335 417 295 344 209]
# |Def Policy Loss: -0.0112| Def Value Loss: 7.7302| Def Grad Norm: 58.3604|
# |Att Policy Loss: -0.0447| Att Value Loss: 2.8840| Att Grad Norm: 2.9287|
# |Def Correct: [190 339 239 326 176] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [145  78  56  18  33] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 56.7%, DoS: 81.3%, Probe: 81.0%, R2L: 94.8%, U2R: 84.2%|
# |Def Entropy: 0.4786| Att Entropy: 3.6466|
# Epoch 28, Average Attack Accuracy: 88.36%
#
# |Epoch 028/100| Time: 29.97|
# |Def Reward: 1548| Att Reward: -407|
# |Def Estimated: [248 439 275 451 187]| Att Labels: [363 452 262 349 174]
# |Def Policy Loss: -0.0130| Def Value Loss: 5.6282| Def Grad Norm: 55.1417|
# |Att Policy Loss: -0.0465| Att Value Loss: 3.0554| Att Grad Norm: 3.4354|
# |Def Correct: [218 388 229 336 146] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [145  64  33  13  28] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 60.1%, DoS: 85.8%, Probe: 87.4%, R2L: 96.3%, U2R: 83.9%|
# |Def Entropy: 0.4620| Att Entropy: 3.6527|
# Epoch 29, Average Attack Accuracy: 88.96%
#
# |Epoch 029/100| Time: 30.21|
# |Def Reward: 1620| Att Reward: -431|
# |Def Estimated: [242 453 241 434 230]| Att Labels: [328 461 258 357 196]
# |Def Policy Loss: -0.0124| Def Value Loss: 5.5421| Def Grad Norm: 49.2015|
# |Att Policy Loss: -0.0415| Att Value Loss: 2.8581| Att Grad Norm: 3.8069|
# |Def Correct: [195 404 211 345 176] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [133  57  47  12  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 59.5%, DoS: 87.6%, Probe: 81.8%, R2L: 96.6%, U2R: 89.8%|
# |Def Entropy: 0.4320| Att Entropy: 3.6523|
# Epoch 30, Average Attack Accuracy: 88.38%
#
# |Epoch 030/100| Time: 30.24|
# |Def Reward: 1588| Att Reward: -409|
# |Def Estimated: [240 427 251 447 235]| Att Labels: [350 418 278 351 203]
# |Def Policy Loss: -0.0119| Def Value Loss: 6.0034| Def Grad Norm: 50.0531|
# |Att Policy Loss: -0.0490| Att Value Loss: 2.4680| Att Grad Norm: 4.2192|
# |Def Correct: [203 361 224 342 181] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [147  57  54   9  22] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 58.0%, DoS: 86.4%, Probe: 80.6%, R2L: 97.4%, U2R: 89.2%|
# |Def Entropy: 0.4410| Att Entropy: 3.6520|
# Epoch 31, Average Attack Accuracy: 87.82%
#
# |Epoch 031/100| Time: 30.68|
# |Def Reward: 1486| Att Reward: -365|
# |Def Estimated: [255 426 251 447 221]| Att Labels: [398 414 268 325 195]
# |Def Policy Loss: -0.0127| Def Value Loss: 5.7610| Def Grad Norm: 54.5741|
# |Att Policy Loss: -0.0417| Att Value Loss: 2.5729| Att Grad Norm: 3.9685|
# |Def Correct: [213 358 219 315 168] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [185  56  49  10  27] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 53.5%, DoS: 86.5%, Probe: 81.7%, R2L: 96.9%, U2R: 86.2%|
# |Def Entropy: 0.4605| Att Entropy: 3.6533|
# Epoch 32, Average Attack Accuracy: 89.37%
#
# |Epoch 032/100| Time: 30.42|
# |Def Reward: 1568| Att Reward: -425|
# |Def Estimated: [251 461 255 431 202]| Att Labels: [365 465 245 351 174]
# |Def Policy Loss: -0.0111| Def Value Loss: 5.6182| Def Grad Norm: 53.4169|
# |Att Policy Loss: -0.0421| Att Value Loss: 2.2348| Att Grad Norm: 4.4721|
# |Def Correct: [213 403 210 341 153] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [152  62  35  10  21] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 58.4%, DoS: 86.7%, Probe: 85.7%, R2L: 97.2%, U2R: 87.9%|
# |Def Entropy: 0.4302| Att Entropy: 3.6548|
# Epoch 33, Average Attack Accuracy: 89.98%
#
# |Epoch 033/100| Time: 29.51|
# |Def Reward: 1558| Att Reward: -429|
# |Def Estimated: [234 469 269 435 193]| Att Labels: [359 477 256 355 153]
# |Def Policy Loss: -0.0102| Def Value Loss: 6.6398| Def Grad Norm: 58.3115|
# |Att Policy Loss: -0.0442| Att Value Loss: 2.5305| Att Grad Norm: 4.8295|
# |Def Correct: [204 422 227 338 134] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [155  55  29  17  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 56.8%, DoS: 88.5%, Probe: 88.7%, R2L: 95.2%, U2R: 87.6%|
# |Def Entropy: 0.4099| Att Entropy: 3.6570|
# Epoch 34, Average Attack Accuracy: 90.38%
#
# |Epoch 034/100| Time: 29.28|
# |Def Reward: 1543| Att Reward: -450|
# |Def Estimated: [266 456 268 416 194]| Att Labels: [391 438 283 326 162]
# |Def Policy Loss: -0.0145| Def Value Loss: 5.2249| Def Grad Norm: 49.7602|
# |Att Policy Loss: -0.0406| Att Value Loss: 2.0569| Att Grad Norm: 4.4609|
# |Def Correct: [231 396 237 321 144] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [160  42  46   5  18] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 59.1%, DoS: 90.4%, Probe: 83.7%, R2L: 98.5%, U2R: 88.9%|
# |Def Entropy: 0.4166| Att Entropy: 3.6566|
# Epoch 35, Average Attack Accuracy: 91.80%
#
# |Epoch 035/100| Time: 29.33|
# |Def Reward: 1616| Att Reward: -476|
# |Def Estimated: [230 479 248 456 187]| Att Labels: [364 473 242 365 156]
# |Def Policy Loss: -0.0120| Def Value Loss: 6.0954| Def Grad Norm: 58.7413|
# |Att Policy Loss: -0.0376| Att Value Loss: 1.8628| Att Grad Norm: 4.7206|
# |Def Correct: [210 423 209 357 146] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [154  50  33   8  10] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 57.7%, DoS: 89.4%, Probe: 86.4%, R2L: 97.8%, U2R: 93.6%|
# |Def Entropy: 0.4216| Att Entropy: 3.6560|
# Epoch 36, Average Attack Accuracy: 90.60%
#
# |Epoch 036/100| Time: 29.97|
# |Def Reward: 1571| Att Reward: -466|
# |Def Estimated: [293 409 266 431 201]| Att Labels: [408 418 265 334 175]
# |Def Policy Loss: -0.0126| Def Value Loss: 6.8823| Def Grad Norm: 59.0761|
# |Att Policy Loss: -0.0450| Att Value Loss: 2.5736| Att Grad Norm: 5.5992|
# |Def Correct: [265 365 234 328 155] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [143  53  31   6  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 65.0%, DoS: 87.3%, Probe: 88.3%, R2L: 98.2%, U2R: 88.6%|
# |Def Entropy: 0.4253| Att Entropy: 3.6539|
# Epoch 37, Average Attack Accuracy: 91.81%
#
# |Epoch 037/100| Time: 29.30|
# |Def Reward: 1580| Att Reward: -490|
# |Def Estimated: [300 453 274 387 186]| Att Labels: [390 464 261 314 171]
# |Def Policy Loss: -0.0118| Def Value Loss: 5.9825| Def Grad Norm: 57.6686|
# |Att Policy Loss: -0.0440| Att Value Loss: 2.5460| Att Grad Norm: 5.5947|
# |Def Correct: [263 400 238 306 158] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [127  64  23   8  13] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 67.4%, DoS: 86.2%, Probe: 91.2%, R2L: 97.5%, U2R: 92.4%|
# |Def Entropy: 0.3980| Att Entropy: 3.6529|
# Epoch 38, Average Attack Accuracy: 91.08%
#
# |Epoch 038/100| Time: 30.48|
# |Def Reward: 1584| Att Reward: -470|
# |Def Estimated: [268 451 244 421 216]| Att Labels: [400 437 248 335 180]
# |Def Policy Loss: -0.0112| Def Value Loss: 5.7739| Def Grad Norm: 56.2953|
# |Att Policy Loss: -0.0409| Att Value Loss: 2.1705| Att Grad Norm: 5.6613|
# |Def Correct: [246 395 214 329 161] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [154  42  34   6  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 61.5%, DoS: 90.4%, Probe: 86.3%, R2L: 98.2%, U2R: 89.4%|
# |Def Entropy: 0.4096| Att Entropy: 3.6550|
# Epoch 39, Average Attack Accuracy: 88.56%
#
# |Epoch 039/100| Time: 30.44|
# |Def Reward: 1540| Att Reward: -428|
# |Def Estimated: [305 412 238 443 202]| Att Labels: [420 419 239 342 180]
# |Def Policy Loss: -0.0132| Def Value Loss: 5.5689| Def Grad Norm: 54.2342|
# |Att Policy Loss: -0.0392| Att Value Loss: 1.9341| Att Grad Norm: 5.0706|
# |Def Correct: [273 363 205 335 151] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [147  56  34   7  29] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 65.0%, DoS: 86.6%, Probe: 85.8%, R2L: 98.0%, U2R: 83.9%|
# |Def Entropy: 0.4052| Att Entropy: 3.6506|
# Epoch 40, Average Attack Accuracy: 90.73%
#
# |Epoch 040/100| Time: 30.32|
# |Def Reward: 1541| Att Reward: -451|
# |Def Estimated: [290 430 238 445 197]| Att Labels: [418 456 227 323 176]
# |Def Policy Loss: -0.0121| Def Value Loss: 5.3010| Def Grad Norm: 54.6457|
# |Att Policy Loss: -0.0440| Att Value Loss: 1.8065| Att Grad Norm: 5.1787|
# |Def Correct: [260 384 200 322 160] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [158  72  27   1  16] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 62.2%, DoS: 84.2%, Probe: 88.1%, R2L: 99.7%, U2R: 90.9%|
# |Def Entropy: 0.4119| Att Entropy: 3.6464|
# Epoch 41, Average Attack Accuracy: 87.76%
#
# |Epoch 041/100| Time: 30.40|
# |Def Reward: 1534| Att Reward: -428|
# |Def Estimated: [304 416 238 462 180]| Att Labels: [397 460 239 330 174]
# |Def Policy Loss: -0.0120| Def Value Loss: 5.0666| Def Grad Norm: 55.1544|
# |Att Policy Loss: -0.0394| Att Value Loss: 2.4006| Att Grad Norm: 6.1103|
# |Def Correct: [267 394 199 326 145] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [130  66  40   4  29] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 67.3%, DoS: 85.7%, Probe: 83.3%, R2L: 98.8%, U2R: 83.3%|
# |Def Entropy: 0.4021| Att Entropy: 3.6418|
# Epoch 42, Average Attack Accuracy: 89.23%
#
# |Epoch 042/100| Time: 30.48|
# |Def Reward: 1578| Att Reward: -467|
# |Def Estimated: [322 386 240 462 190]| Att Labels: [416 399 266 333 186]
# |Def Policy Loss: -0.0104| Def Value Loss: 4.6985| Def Grad Norm: 51.1170|
# |Att Policy Loss: -0.0386| Att Value Loss: 1.6224| Att Grad Norm: 5.5761|
# |Def Correct: [294 344 217 329 168] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [122  55  49   4  18] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 70.7%, DoS: 86.2%, Probe: 81.6%, R2L: 98.8%, U2R: 90.3%|
# |Def Entropy: 0.4088| Att Entropy: 3.6410|
# Epoch 43, Average Attack Accuracy: 88.35%
#
# |Epoch 043/100| Time: 30.89|
# |Def Reward: 1510| Att Reward: -431|
# |Def Estimated: [319 392 238 423 228]| Att Labels: [425 419 265 296 195]
# |Def Policy Loss: -0.0149| Def Value Loss: 4.7259| Def Grad Norm: 51.5521|
# |Att Policy Loss: -0.0426| Att Value Loss: 1.9564| Att Grad Norm: 5.5238|
# |Def Correct: [290 357 216 293 171] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [135  62  49   3  24] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 68.2%, DoS: 85.2%, Probe: 81.5%, R2L: 99.0%, U2R: 87.7%|
# |Def Entropy: 0.4200| Att Entropy: 3.6417|
# Epoch 44, Average Attack Accuracy: 90.13%
#
# |Epoch 044/100| Time: 30.56|
# |Def Reward: 1522| Att Reward: -460|
# |Def Estimated: [327 415 237 410 211]| Att Labels: [452 413 247 300 188]
# |Def Policy Loss: -0.0135| Def Value Loss: 4.0010| Def Grad Norm: 47.7981|
# |Att Policy Loss: -0.0462| Att Value Loss: 1.7141| Att Grad Norm: 5.0770|
# |Def Correct: [303 362 211 299 165] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [149  51  36   1  23] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 67.0%, DoS: 87.7%, Probe: 85.4%, R2L: 99.7%, U2R: 87.8%|
# |Def Entropy: 0.4080| Att Entropy: 3.6459|
# Epoch 45, Average Attack Accuracy: 91.37%
#
# |Epoch 045/100| Time: 30.51|
# |Def Reward: 1580| Att Reward: -489|
# |Def Estimated: [293 451 232 393 231]| Att Labels: [408 451 246 299 196]
# |Def Policy Loss: -0.0119| Def Value Loss: 5.1226| Def Grad Norm: 57.2521|
# |Att Policy Loss: -0.0416| Att Value Loss: 2.0255| Att Grad Norm: 5.8835|
# |Def Correct: [271 410 211 293 178] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [137  41  35   6  18] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 66.4%, DoS: 90.9%, Probe: 85.8%, R2L: 98.0%, U2R: 90.8%|
# |Def Entropy: 0.3601| Att Entropy: 3.6476|
# Epoch 46, Average Attack Accuracy: 91.49%
#
# |Epoch 046/100| Time: 31.46|
# |Def Reward: 1543| Att Reward: -459|
# |Def Estimated: [274 467 237 405 217]| Att Labels: [412 462 236 300 190]
# |Def Policy Loss: -0.0137| Def Value Loss: 5.0962| Def Grad Norm: 54.0674|
# |Att Policy Loss: -0.0408| Att Value Loss: 1.9803| Att Grad Norm: 5.6710|
# |Def Correct: [249 410 211 295 170] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [163  52  25   5  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 60.4%, DoS: 88.7%, Probe: 89.4%, R2L: 98.3%, U2R: 89.5%|
# |Def Entropy: 0.3599| Att Entropy: 3.6443|
# Epoch 47, Average Attack Accuracy: 91.57%
#
# |Epoch 047/100| Time: 30.80|
# |Def Reward: 1587| Att Reward: -486|
# |Def Estimated: [262 452 262 420 204]| Att Labels: [391 444 268 323 174]
# |Def Policy Loss: -0.0105| Def Value Loss: 6.5718| Def Grad Norm: 66.5254|
# |Att Policy Loss: -0.0421| Att Value Loss: 1.8510| Att Grad Norm: 5.4357|
# |Def Correct: [239 405 232 323 154] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [152  39  36   0  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 61.1%, DoS: 91.2%, Probe: 86.6%, R2L: 100.0%, U2R: 88.5%|
# |Def Entropy: 0.3305| Att Entropy: 3.6439|
# Epoch 48, Average Attack Accuracy: 92.09%
#
# |Epoch 048/100| Time: 30.52|
# |Def Reward: 1538| Att Reward: -488|
# |Def Estimated: [289 475 241 374 221]| Att Labels: [432 456 246 290 176]
# |Def Policy Loss: -0.0120| Def Value Loss: 5.8253| Def Grad Norm: 51.6820|
# |Att Policy Loss: -0.0413| Att Value Loss: 1.4515| Att Grad Norm: 5.0963|
# |Def Correct: [271 420 215 289 157] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [161  36  31   1  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 62.7%, DoS: 92.1%, Probe: 87.4%, R2L: 99.7%, U2R: 89.2%|
# |Def Entropy: 0.3360| Att Entropy: 3.6384|
# Epoch 49, Average Attack Accuracy: 92.45%
#
# |Epoch 049/100| Time: 30.52|
# |Def Reward: 1506| Att Reward: -490|
# |Def Estimated: [291 467 281 359 202]| Att Labels: [442 452 269 268 169]
# |Def Policy Loss: -0.0111| Def Value Loss: 5.9089| Def Grad Norm: 58.5002|
# |Att Policy Loss: -0.0416| Att Value Loss: 1.9420| Att Grad Norm: 6.2302|
# |Def Correct: [278 421 248 266 144] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [164  31  21   2  25] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 62.9%, DoS: 93.1%, Probe: 92.2%, R2L: 99.3%, U2R: 85.2%|
# |Def Entropy: 0.3270| Att Entropy: 3.6337|
# Epoch 50, Average Attack Accuracy: 92.10%
#
# |Epoch 050/100| Time: 30.63|
# |Def Reward: 1468| Att Reward: -496|
# |Def Estimated: [342 460 264 333 201]| Att Labels: [478 450 261 244 167]
# |Def Policy Loss: -0.0099| Def Value Loss: 3.6304| Def Grad Norm: 46.0362|
# |Att Policy Loss: -0.0403| Att Value Loss: 1.6736| Att Grad Norm: 5.6451|
# |Def Correct: [323 417 230 243 147] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [155  33  31   1  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 67.6%, DoS: 92.7%, Probe: 88.1%, R2L: 99.6%, U2R: 88.0%|
# |Def Entropy: 0.3373| Att Entropy: 3.6225|
# Epoch 51, Average Attack Accuracy: 91.94%
#
# |Epoch 051/100| Time: 31.54|
# |Def Reward: 1458| Att Reward: -478|
# |Def Estimated: [322 494 237 331 216]| Att Labels: [478 459 244 241 178]
# |Def Policy Loss: -0.0097| Def Value Loss: 4.6211| Def Grad Norm: 50.2510|
# |Att Policy Loss: -0.0463| Att Value Loss: 1.5443| Att Grad Norm: 5.7875|
# |Def Correct: [306 433 212 237 157] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [172  26  32   4  21] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 64.0%, DoS: 94.3%, Probe: 86.9%, R2L: 98.3%, U2R: 88.2%|
# |Def Entropy: 0.3433| Att Entropy: 3.6238|
# Epoch 52, Average Attack Accuracy: 91.69%
#
# |Epoch 052/100| Time: 30.63|
# |Def Reward: 1428| Att Reward: -468|
# |Def Estimated: [338 462 283 318 199]| Att Labels: [495 421 276 239 169]
# |Def Policy Loss: -0.0096| Def Value Loss: 5.3701| Def Grad Norm: 59.0106|
# |Att Policy Loss: -0.0416| Att Value Loss: 2.0049| Att Grad Norm: 5.9280|
# |Def Correct: [323 386 251 235 145] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [172  35  25   4  24] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 65.3%, DoS: 91.7%, Probe: 90.9%, R2L: 98.3%, U2R: 85.8%|
# |Def Entropy: 0.3436| Att Entropy: 3.6142|
# Epoch 53, Average Attack Accuracy: 92.19%
#
# |Epoch 053/100| Time: 30.30|
# |Def Reward: 1419| Att Reward: -473|
# |Def Estimated: [345 470 263 333 189]| Att Labels: [516 424 256 242 162]
# |Def Policy Loss: -0.0125| Def Value Loss: 4.8203| Def Grad Norm: 51.1130|
# |Att Policy Loss: -0.0400| Att Value Loss: 1.7762| Att Grad Norm: 5.9244|
# |Def Correct: [334 386 229 242 143] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [182  38  27   0  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 64.7%, DoS: 91.0%, Probe: 89.5%, R2L: 100.0%, U2R: 88.3%|
# |Def Entropy: 0.3567| Att Entropy: 3.6216|
# Epoch 54, Average Attack Accuracy: 92.48%
#
# |Epoch 054/100| Time: 30.43|
# |Def Reward: 1498| Att Reward: -494|
# |Def Estimated: [342 456 266 350 186]| Att Labels: [485 426 242 272 175]
# |Def Policy Loss: -0.0111| Def Value Loss: 5.0104| Def Grad Norm: 56.4740|
# |Att Policy Loss: -0.0412| Att Value Loss: 2.0453| Att Grad Norm: 5.9594|
# |Def Correct: [326 392 228 268 149] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [159  34  14   4  26] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 67.2%, DoS: 92.0%, Probe: 94.2%, R2L: 98.5%, U2R: 85.1%|
# |Def Entropy: 0.3360| Att Entropy: 3.6195|
# Epoch 55, Average Attack Accuracy: 94.46%
#
# |Epoch 055/100| Time: 30.59|
# |Def Reward: 1478| Att Reward: -506|
# |Def Estimated: [325 494 245 341 195]| Att Labels: [496 449 235 257 163]
# |Def Policy Loss: -0.0100| Def Value Loss: 4.5246| Def Grad Norm: 52.5601|
# |Att Policy Loss: -0.0358| Att Value Loss: 1.3220| Att Grad Norm: 5.0531|
# |Def Correct: [307 422 220 254 149] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [189  27  15   3  14] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 61.9%, DoS: 94.0%, Probe: 93.6%, R2L: 98.8%, U2R: 91.4%|
# |Def Entropy: 0.3352| Att Entropy: 3.6199|
# Epoch 56, Average Attack Accuracy: 93.56%
#
# |Epoch 056/100| Time: 30.60|
# |Def Reward: 1484| Att Reward: -504|
# |Def Estimated: [339 471 268 323 199]| Att Labels: [494 426 253 257 170]
# |Def Policy Loss: -0.0088| Def Value Loss: 4.9417| Def Grad Norm: 56.1691|
# |Att Policy Loss: -0.0401| Att Value Loss: 1.7529| Att Grad Norm: 5.9035|
# |Def Correct: [326 389 240 255 151] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [168  37  13   2  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 66.0%, DoS: 91.3%, Probe: 94.9%, R2L: 99.2%, U2R: 88.8%|
# |Def Entropy: 0.3280| Att Entropy: 3.6147|
# Epoch 57, Average Attack Accuracy: 94.08%
#
# |Epoch 057/100| Time: 30.63|
# |Def Reward: 1486| Att Reward: -524|
# |Def Estimated: [373 477 245 309 196]| Att Labels: [526 418 231 234 191]
# |Def Policy Loss: -0.0100| Def Value Loss: 5.1279| Def Grad Norm: 53.0302|
# |Att Policy Loss: -0.0376| Att Value Loss: 1.8201| Att Grad Norm: 5.7332|
# |Def Correct: [365 400 219 229 168] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [161  18  12   5  23] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 69.4%, DoS: 95.7%, Probe: 94.8%, R2L: 97.9%, U2R: 88.0%|
# |Def Entropy: 0.3119| Att Entropy: 3.6105|
# Epoch 58, Average Attack Accuracy: 94.00%
#
# |Epoch 058/100| Time: 30.88|
# |Def Reward: 1454| Att Reward: -514|
# |Def Estimated: [372 465 272 299 192]| Att Labels: [528 418 250 236 168]
# |Def Policy Loss: -0.0086| Def Value Loss: 4.1531| Def Grad Norm: 46.4231|
# |Att Policy Loss: -0.0400| Att Value Loss: 1.5713| Att Grad Norm: 5.4817|
# |Def Correct: [357 393 237 231 150] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [171  25  13   5  18] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 67.6%, DoS: 94.0%, Probe: 94.8%, R2L: 97.9%, U2R: 89.3%|
# |Def Entropy: 0.3125| Att Entropy: 3.6027|
# Epoch 59, Average Attack Accuracy: 94.14%
#
# |Epoch 059/100| Time: 31.09|
# |Def Reward: 1551| Att Reward: -547|
# |Def Estimated: [359 476 249 300 216]| Att Labels: [482 434 239 244 201]
# |Def Policy Loss: -0.0085| Def Value Loss: 4.4414| Def Grad Norm: 47.3047|
# |Att Policy Loss: -0.0371| Att Value Loss: 1.4864| Att Grad Norm: 6.1518|
# |Def Correct: [348 412 225 239 180] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [134  22  14   5  21] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 72.2%, DoS: 94.9%, Probe: 94.1%, R2L: 98.0%, U2R: 89.6%|
# |Def Entropy: 0.2989| Att Entropy: 3.5930|
# Epoch 60, Average Attack Accuracy: 93.09%
#
# |Epoch 060/100| Time: 30.42|
# |Def Reward: 1536| Att Reward: -536|
# |Def Estimated: [371 450 258 321 200]| Att Labels: [489 430 236 258 187]
# |Def Policy Loss: -0.0123| Def Value Loss: 3.7192| Def Grad Norm: 43.0165|
# |Att Policy Loss: -0.0370| Att Value Loss: 1.6171| Att Grad Norm: 5.9347|
# |Def Correct: [356 405 215 255 165] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [133  25  21   3  22] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 72.8%, DoS: 94.2%, Probe: 91.1%, R2L: 98.8%, U2R: 88.2%|
# |Def Entropy: 0.3055| Att Entropy: 3.5870|
# Epoch 61, Average Attack Accuracy: 92.05%
#
# |Epoch 061/100| Time: 30.91|
# |Def Reward: 1534| Att Reward: -526|
# |Def Estimated: [401 446 204 327 222]| Att Labels: [510 423 204 269 194]
# |Def Policy Loss: -0.0111| Def Value Loss: 4.8156| Def Grad Norm: 53.3035|
# |Att Policy Loss: -0.0328| Att Value Loss: 1.7245| Att Grad Norm: 6.5235|
# |Def Correct: [379 392 176 265 176] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [131  31  28   4  18] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 74.3%, DoS: 92.7%, Probe: 86.3%, R2L: 98.5%, U2R: 90.7%|
# |Def Entropy: 0.3048| Att Entropy: 3.5823|
# Epoch 62, Average Attack Accuracy: 92.91%
#
# |Epoch 062/100| Time: 30.43|
# |Def Reward: 1461| Att Reward: -530|
# |Def Estimated: [424 453 247 271 205]| Att Labels: [537 431 233 213 186]
# |Def Policy Loss: -0.0077| Def Value Loss: 4.8528| Def Grad Norm: 54.8278|
# |Att Policy Loss: -0.0393| Att Value Loss: 1.4313| Att Grad Norm: 5.7180|
# |Def Correct: [405 400 214 207 167] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [132  31  19   6  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 75.4%, DoS: 92.8%, Probe: 91.8%, R2L: 97.2%, U2R: 89.8%|
# |Def Entropy: 0.3326| Att Entropy: 3.5783|
# Epoch 63, Average Attack Accuracy: 92.60%
#
# |Epoch 063/100| Time: 30.54|
# |Def Reward: 1516| Att Reward: -546|
# |Def Estimated: [418 422 264 293 203]| Att Labels: [501 431 247 237 184]
# |Def Policy Loss: -0.0088| Def Value Loss: 3.9163| Def Grad Norm: 46.3597|
# |Att Policy Loss: -0.0388| Att Value Loss: 1.7201| Att Grad Norm: 6.2353|
# |Def Correct: [396 395 230 230 163] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [105  36  17   7  21] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 79.0%, DoS: 91.6%, Probe: 93.1%, R2L: 97.0%, U2R: 88.6%|
# |Def Entropy: 0.2956| Att Entropy: 3.5769|
# Epoch 64, Average Attack Accuracy: 92.37%
#
# |Epoch 064/100| Time: 30.49|
# |Def Reward: 1487| Att Reward: -524|
# |Def Estimated: [447 387 223 345 198]| Att Labels: [572 356 223 268 181]
# |Def Policy Loss: -0.0105| Def Value Loss: 4.7272| Def Grad Norm: 46.4661|
# |Att Policy Loss: -0.0378| Att Value Loss: 1.9076| Att Grad Norm: 6.3695|
# |Def Correct: [431 335 199 262 160] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [141  21  24   6  21] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 75.3%, DoS: 94.1%, Probe: 89.2%, R2L: 97.8%, U2R: 88.4%|
# |Def Entropy: 0.3177| Att Entropy: 3.5770|
# Epoch 65, Average Attack Accuracy: 92.39%
#
# |Epoch 065/100| Time: 30.42|
# |Def Reward: 1512| Att Reward: -553|
# |Def Estimated: [462 376 248 329 185]| Att Labels: [553 363 248 258 178]
# |Def Policy Loss: -0.0083| Def Value Loss: 5.4750| Def Grad Norm: 53.7600|
# |Att Policy Loss: -0.0367| Att Value Loss: 1.6459| Att Grad Norm: 6.0200|
# |Def Correct: [446 332 224 254 159] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [107  31  24   4  19] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 80.7%, DoS: 91.5%, Probe: 90.3%, R2L: 98.4%, U2R: 89.3%|
# |Def Entropy: 0.3080| Att Entropy: 3.5656|
# Epoch 66, Average Attack Accuracy: 91.97%
#
# |Epoch 066/100| Time: 30.40|
# |Def Reward: 1477| Att Reward: -522|
# |Def Estimated: [424 451 223 307 195]| Att Labels: [527 422 233 244 174]
# |Def Policy Loss: -0.0092| Def Value Loss: 5.0877| Def Grad Norm: 52.0100|
# |Att Policy Loss: -0.0307| Att Value Loss: 1.4501| Att Grad Norm: 5.7578|
# |Def Correct: [394 396 201 238 157] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [133  26  32   6  17] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 74.8%, DoS: 93.8%, Probe: 86.3%, R2L: 97.5%, U2R: 90.2%|
# |Def Entropy: 0.3133| Att Entropy: 3.5597|
# Epoch 67, Average Attack Accuracy: 92.07%
#
# |Epoch 067/100| Time: 30.70|
# |Def Reward: 1473| Att Reward: -526|
# |Def Estimated: [431 426 240 291 212]| Att Labels: [528 418 243 223 188]
# |Def Policy Loss: -0.0089| Def Value Loss: 4.9771| Def Grad Norm: 53.9841|
# |Att Policy Loss: -0.0385| Att Value Loss: 1.5777| Att Grad Norm: 5.9337|
# |Def Correct: [404 388 213 216 171] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [124  30  30   7  17] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 76.5%, DoS: 92.8%, Probe: 87.7%, R2L: 96.9%, U2R: 91.0%|
# |Def Entropy: 0.3188| Att Entropy: 3.5551|
# Epoch 68, Average Attack Accuracy: 91.51%
#
# |Epoch 068/100| Time: 30.48|
# |Def Reward: 1482| Att Reward: -502|
# |Def Estimated: [416 407 247 316 214]| Att Labels: [516 403 243 250 188]
# |Def Policy Loss: -0.0086| Def Value Loss: 5.1231| Def Grad Norm: 54.7608|
# |Att Policy Loss: -0.0346| Att Value Loss: 2.0704| Att Grad Norm: 6.6465|
# |Def Correct: [384 357 217 247 168] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [132  46  26   3  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 74.4%, DoS: 88.6%, Probe: 89.3%, R2L: 98.8%, U2R: 89.4%|
# |Def Entropy: 0.3304| Att Entropy: 3.5547|
# Epoch 69, Average Attack Accuracy: 91.80%
#
# |Epoch 069/100| Time: 31.04|
# |Def Reward: 1460| Att Reward: -521|
# |Def Estimated: [458 403 238 310 191]| Att Labels: [544 422 223 250 161]
# |Def Policy Loss: -0.0103| Def Value Loss: 4.8798| Def Grad Norm: 52.6427|
# |Att Policy Loss: -0.0313| Att Value Loss: 2.2370| Att Grad Norm: 7.3277|
# |Def Correct: [423 367 201 247 147] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [121  55  22   3  14] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.8%, DoS: 87.0%, Probe: 90.1%, R2L: 98.8%, U2R: 91.3%|
# |Def Entropy: 0.3344| Att Entropy: 3.5582|
# Epoch 70, Average Attack Accuracy: 92.06%
#
# |Epoch 070/100| Time: 30.61|
# |Def Reward: 1461| Att Reward: -522|
# |Def Estimated: [456 421 221 298 204]| Att Labels: [541 440 210 232 177]
# |Def Policy Loss: -0.0099| Def Value Loss: 3.8841| Def Grad Norm: 48.3111|
# |Att Policy Loss: -0.0394| Att Value Loss: 1.3121| Att Grad Norm: 5.4300|
# |Def Correct: [422 384 192 230 160] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [119  56  18   2  17] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 78.0%, DoS: 87.3%, Probe: 91.4%, R2L: 99.1%, U2R: 90.4%|
# |Def Entropy: 0.3314| Att Entropy: 3.5553|
# Epoch 71, Average Attack Accuracy: 92.39%
#
# |Epoch 071/100| Time: 30.67|
# |Def Reward: 1433| Att Reward: -514|
# |Def Estimated: [445 427 236 312 180]| Att Labels: [549 435 222 238 156]
# |Def Policy Loss: -0.0101| Def Value Loss: 4.7679| Def Grad Norm: 49.8218|
# |Att Policy Loss: -0.0328| Att Value Loss: 1.4914| Att Grad Norm: 6.0778|
# |Def Correct: [413 383 207 233 141] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [136  52  15   5  15] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 75.2%, DoS: 88.0%, Probe: 93.2%, R2L: 97.9%, U2R: 90.4%|
# |Def Entropy: 0.3261| Att Entropy: 3.5478|
# Epoch 72, Average Attack Accuracy: 93.99%
#
# |Epoch 072/100| Time: 30.42|
# |Def Reward: 1464| Att Reward: -548|
# |Def Estimated: [467 422 216 277 218]| Att Labels: [580 423 191 221 185]
# |Def Policy Loss: -0.0120| Def Value Loss: 3.3764| Def Grad Norm: 45.5259|
# |Att Policy Loss: -0.0359| Att Value Loss: 1.3280| Att Grad Norm: 6.1341|
# |Def Correct: [442 383 175 218 176] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [138  40  16   3   9] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 76.2%, DoS: 90.5%, Probe: 91.6%, R2L: 98.6%, U2R: 95.1%|
# |Def Entropy: 0.3244| Att Entropy: 3.5397|
# Epoch 73, Average Attack Accuracy: 93.45%
#
# |Epoch 073/100| Time: 30.68|
# |Def Reward: 1554| Att Reward: -554|
# |Def Estimated: [431 409 239 318 203]| Att Labels: [516 410 216 259 199]
# |Def Policy Loss: -0.0075| Def Value Loss: 4.9807| Def Grad Norm: 54.8524|
# |Att Policy Loss: -0.0362| Att Value Loss: 1.6423| Att Grad Norm: 5.6188|
# |Def Correct: [404 367 203 256 182] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [112  43  13   3  17] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 78.3%, DoS: 89.5%, Probe: 94.0%, R2L: 98.8%, U2R: 91.5%|
# |Def Entropy: 0.2990| Att Entropy: 3.5326|
# Epoch 74, Average Attack Accuracy: 94.30%
#
# |Epoch 074/100| Time: 30.59|
# |Def Reward: 1480| Att Reward: -567|
# |Def Estimated: [491 401 241 288 179]| Att Labels: [582 402 212 232 172]
# |Def Policy Loss: -0.0067| Def Value Loss: 3.4671| Def Grad Norm: 43.8937|
# |Att Policy Loss: -0.0392| Att Value Loss: 1.2502| Att Grad Norm: 5.8632|
# |Def Correct: [463 362 206 229 157] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [119  40   6   3  15] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 79.6%, DoS: 90.0%, Probe: 97.2%, R2L: 98.7%, U2R: 91.3%|
# |Def Entropy: 0.2893| Att Entropy: 3.5351|
# Epoch 75, Average Attack Accuracy: 94.01%
#
# |Epoch 075/100| Time: 30.50|
# |Def Reward: 1462| Att Reward: -558|
# |Def Estimated: [457 451 216 289 187]| Att Labels: [559 450 207 228 156]
# |Def Policy Loss: -0.0089| Def Value Loss: 3.6356| Def Grad Norm: 44.9222|
# |Att Policy Loss: -0.0387| Att Value Loss: 1.2453| Att Grad Norm: 5.5302|
# |Def Correct: [432 411 194 225 144] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [127  39  13   3  12] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.3%, DoS: 91.3%, Probe: 93.7%, R2L: 98.7%, U2R: 92.3%|
# |Def Entropy: 0.2791| Att Entropy: 3.5380|
# Epoch 76, Average Attack Accuracy: 94.36%
#
# |Epoch 076/100| Time: 30.57|
# |Def Reward: 1554| Att Reward: -578|
# |Def Estimated: [461 396 213 307 223]| Att Labels: [548 406 196 249 201]
# |Def Policy Loss: -0.0095| Def Value Loss: 4.0797| Def Grad Norm: 48.3270|
# |Att Policy Loss: -0.0312| Att Value Loss: 1.1587| Att Grad Norm: 5.5988|
# |Def Correct: [438 368 184 245 190] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [110  38  12   4  11] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 79.9%, DoS: 90.6%, Probe: 93.9%, R2L: 98.4%, U2R: 94.5%|
# |Def Entropy: 0.2797| Att Entropy: 3.5278|
# Epoch 77, Average Attack Accuracy: 93.75%
#
# |Epoch 077/100| Time: 30.51|
# |Def Reward: 1530| Att Reward: -550|
# |Def Estimated: [448 393 234 304 221]| Att Labels: [545 400 203 258 194]
# |Def Policy Loss: -0.0118| Def Value Loss: 4.0554| Def Grad Norm: 48.6136|
# |Att Policy Loss: -0.0364| Att Value Loss: 1.6196| Att Grad Norm: 6.2698|
# |Def Correct: [423 356 195 256 176] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [122  44   8   2  18] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.6%, DoS: 89.0%, Probe: 96.1%, R2L: 99.2%, U2R: 90.7%|
# |Def Entropy: 0.2909| Att Entropy: 3.5264|
# Epoch 78, Average Attack Accuracy: 92.87%
#
# |Epoch 078/100| Time: 30.49|
# |Def Reward: 1463| Att Reward: -505|
# |Def Estimated: [433 421 217 316 213]| Att Labels: [560 423 179 240 198]
# |Def Policy Loss: -0.0095| Def Value Loss: 4.6815| Def Grad Norm: 55.5081|
# |Att Policy Loss: -0.0337| Att Value Loss: 1.7479| Att Grad Norm: 6.5277|
# |Def Correct: [411 378 170 237 175] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [149  45   9   3  23] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 73.4%, DoS: 89.4%, Probe: 95.0%, R2L: 98.8%, U2R: 88.4%|
# |Def Entropy: 0.3221| Att Entropy: 3.5131|
# Epoch 79, Average Attack Accuracy: 92.72%
#
# |Epoch 079/100| Time: 30.96|
# |Def Reward: 1480| Att Reward: -528|
# |Def Estimated: [454 404 233 289 220]| Att Labels: [540 421 217 215 207]
# |Def Policy Loss: -0.0106| Def Value Loss: 4.5482| Def Grad Norm: 50.9312|
# |Att Policy Loss: -0.0341| Att Value Loss: 1.2754| Att Grad Norm: 5.8162|
# |Def Correct: [418 372 201 214 187] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [122  49  16   1  20] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.4%, DoS: 88.4%, Probe: 92.6%, R2L: 99.5%, U2R: 90.3%|
# |Def Entropy: 0.3113| Att Entropy: 3.5155|
# Epoch 80, Average Attack Accuracy: 92.81%
#
# |Epoch 080/100| Time: 30.87|
# |Def Reward: 1474| Att Reward: -548|
# |Def Estimated: [480 409 198 320 193]| Att Labels: [582 408 193 245 172]
# |Def Policy Loss: -0.0097| Def Value Loss: 3.7906| Def Grad Norm: 44.6592|
# |Att Policy Loss: -0.0347| Att Value Loss: 1.3189| Att Grad Norm: 6.0471|
# |Def Correct: [459 370 175 243 156] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [123  38  18   2  16] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 78.9%, DoS: 90.7%, Probe: 90.7%, R2L: 99.2%, U2R: 90.7%|
# |Def Entropy: 0.3022| Att Entropy: 3.5099|
# Epoch 81, Average Attack Accuracy: 93.80%
#
# |Epoch 081/100| Time: 31.21|
# |Def Reward: 1430| Att Reward: -531|
# |Def Estimated: [453 443 220 288 196]| Att Labels: [574 429 211 214 172]
# |Def Policy Loss: -0.0114| Def Value Loss: 5.0753| Def Grad Norm: 54.7183|
# |Att Policy Loss: -0.0381| Att Value Loss: 1.5970| Att Grad Norm: 6.4033|
# |Def Correct: [427 386 196 210 162] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [147  43  15   4  10] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 74.4%, DoS: 90.0%, Probe: 92.9%, R2L: 98.1%, U2R: 94.2%|
# |Def Entropy: 0.3312| Att Entropy: 3.5217|
# Epoch 82, Average Attack Accuracy: 93.95%
#
# |Epoch 082/100| Time: 30.87|
# |Def Reward: 1460| Att Reward: -550|
# |Def Estimated: [455 455 222 294 174]| Att Labels: [552 465 197 232 154]
# |Def Policy Loss: -0.0090| Def Value Loss: 4.3582| Def Grad Norm: 48.8053|
# |Att Policy Loss: -0.0349| Att Value Loss: 1.5956| Att Grad Norm: 6.2994|
# |Def Correct: [429 416 191 227 141] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [123  49   6   5  13] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.7%, DoS: 89.5%, Probe: 97.0%, R2L: 97.8%, U2R: 91.6%|
# |Def Entropy: 0.2894| Att Entropy: 3.5213|
# Epoch 83, Average Attack Accuracy: 94.43%
#
# |Epoch 083/100| Time: 31.03|
# |Def Reward: 1466| Att Reward: -572|
# |Def Estimated: [479 420 219 315 167]| Att Labels: [582 434 199 234 151]
# |Def Policy Loss: -0.0088| Def Value Loss: 3.5097| Def Grad Norm: 44.2693|
# |Att Policy Loss: -0.0367| Att Value Loss: 1.2398| Att Grad Norm: 6.0287|
# |Def Correct: [457 402 189 231 138] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [125  32  10   3  13] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 78.5%, DoS: 92.6%, Probe: 95.0%, R2L: 98.7%, U2R: 91.4%|
# |Def Entropy: 0.2787| Att Entropy: 3.5291|
# Epoch 84, Average Attack Accuracy: 94.04%
#
# |Epoch 084/100| Time: 31.13|
# |Def Reward: 1458| Att Reward: -556|
# |Def Estimated: [450 422 252 322 154]| Att Labels: [558 437 224 250 131]
# |Def Policy Loss: -0.0079| Def Value Loss: 4.1947| Def Grad Norm: 46.5507|
# |Att Policy Loss: -0.0348| Att Value Loss: 1.7483| Att Grad Norm: 6.9370|
# |Def Correct: [426 395 211 248 121] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [132  42  13   2  10] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 76.3%, DoS: 90.4%, Probe: 94.2%, R2L: 99.2%, U2R: 92.4%|
# |Def Entropy: 0.2816| Att Entropy: 3.5282|
# Epoch 85, Average Attack Accuracy: 94.56%
#
# |Epoch 085/100| Time: 31.35|
# |Def Reward: 1462| Att Reward: -560|
# |Def Estimated: [458 439 227 303 173]| Att Labels: [580 420 208 233 159]
# |Def Policy Loss: -0.0109| Def Value Loss: 4.5867| Def Grad Norm: 48.4580|
# |Att Policy Loss: -0.0340| Att Value Loss: 1.1463| Att Grad Norm: 5.2114|
# |Def Correct: [439 389 196 232 146] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [141  31  12   1  13] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 75.7%, DoS: 92.6%, Probe: 94.2%, R2L: 99.6%, U2R: 91.8%|
# |Def Entropy: 0.2821| Att Entropy: 3.5166|
# Epoch 86, Average Attack Accuracy: 94.52%
#
# |Epoch 086/100| Time: 31.01|
# |Def Reward: 1488| Att Reward: -570|
# |Def Estimated: [459 456 232 271 182]| Att Labels: [549 471 188 224 168]
# |Def Policy Loss: -0.0090| Def Value Loss: 4.0429| Def Grad Norm: 50.5916|
# |Att Policy Loss: -0.0307| Att Value Loss: 1.0610| Att Grad Norm: 5.2762|
# |Def Correct: [434 428 181 221 155] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [115  43   7   3  13] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 79.1%, DoS: 90.9%, Probe: 96.3%, R2L: 98.7%, U2R: 92.3%|
# |Def Entropy: 0.2705| Att Entropy: 3.5348|
# Epoch 87, Average Attack Accuracy: 94.45%
#
# |Epoch 087/100| Time: 30.97|
# |Def Reward: 1540| Att Reward: -609|
# |Def Estimated: [450 487 205 296 162]| Att Labels: [529 466 209 247 149]
# |Def Policy Loss: -0.0093| Def Value Loss: 3.1270| Def Grad Norm: 40.6018|
# |Att Policy Loss: -0.0317| Att Value Loss: 1.1706| Att Grad Norm: 5.7760|
# |Def Correct: [433 444 191 245 137] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [96 22 18  2 12] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 81.9%, DoS: 95.3%, Probe: 91.4%, R2L: 99.2%, U2R: 91.9%|
# |Def Entropy: 0.2563| Att Entropy: 3.5392|
# Epoch 88, Average Attack Accuracy: 93.60%
#
# |Epoch 088/100| Time: 30.68|
# |Def Reward: 1486| Att Reward: -572|
# |Def Estimated: [500 410 225 316 149]| Att Labels: [586 405 203 263 143]
# |Def Policy Loss: -0.0087| Def Value Loss: 3.5787| Def Grad Norm: 43.2693|
# |Att Policy Loss: -0.0316| Att Value Loss: 1.3112| Att Grad Norm: 6.0124|
# |Def Correct: [474 373 193 257 128] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [112  32  10   6  15] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 80.9%, DoS: 92.1%, Probe: 95.1%, R2L: 97.7%, U2R: 89.5%|
# |Def Entropy: 0.2756| Att Entropy: 3.5315|
# Epoch 89, Average Attack Accuracy: 93.58%
#
# |Epoch 089/100| Time: 31.02|
# |Def Reward: 1492| Att Reward: -542|
# |Def Estimated: [424 444 232 323 177]| Att Labels: [546 422 209 256 167]
# |Def Policy Loss: -0.0066| Def Value Loss: 4.3742| Def Grad Norm: 47.6837|
# |Att Policy Loss: -0.0320| Att Value Loss: 1.5640| Att Grad Norm: 6.4662|
# |Def Correct: [402 392 191 255 151] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [144  30  18   1  16] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 73.6%, DoS: 92.9%, Probe: 91.4%, R2L: 99.6%, U2R: 90.4%|
# |Def Entropy: 0.2916| Att Entropy: 3.5350|
# Epoch 90, Average Attack Accuracy: 94.54%
#
# |Epoch 090/100| Time: 30.98|
# |Def Reward: 1470| Att Reward: -570|
# |Def Estimated: [481 407 238 324 150]| Att Labels: [594 407 201 261 137]
# |Def Policy Loss: -0.0097| Def Value Loss: 4.3598| Def Grad Norm: 50.2473|
# |Att Policy Loss: -0.0276| Att Value Loss: 1.2218| Att Grad Norm: 5.3585|
# |Def Correct: [461 374 194 259 124] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [133  33   7   2  13] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.6%, DoS: 91.9%, Probe: 96.5%, R2L: 99.2%, U2R: 90.5%|
# |Def Entropy: 0.3030| Att Entropy: 3.5181|
# Epoch 91, Average Attack Accuracy: 91.22%
#
# |Epoch 091/100| Time: 30.73|
# |Def Reward: 1437| Att Reward: -528|
# |Def Estimated: [464 486 195 313 142]| Att Labels: [573 455 177 251 144]
# |Def Policy Loss: -0.0068| Def Value Loss: 4.8932| Def Grad Norm: 51.5858|
# |Att Policy Loss: -0.0341| Att Value Loss: 1.6868| Att Grad Norm: 6.6151|
# |Def Correct: [439 428 154 247 123] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [134  27  23   4  21] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 76.6%, DoS: 94.1%, Probe: 87.0%, R2L: 98.4%, U2R: 85.4%|
# |Def Entropy: 0.2975| Att Entropy: 3.5239|
# Epoch 92, Average Attack Accuracy: 95.67%
#
# |Epoch 092/100| Time: 30.65|
# |Def Reward: 1534| Att Reward: -591|
# |Def Estimated: [433 454 226 324 163]| Att Labels: [556 423 200 277 144]
# |Def Policy Loss: -0.0085| Def Value Loss: 5.1153| Def Grad Norm: 52.7920|
# |Att Policy Loss: -0.0320| Att Value Loss: 1.1447| Att Grad Norm: 5.3754|
# |Def Correct: [424 405 190 272 135] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [132  18  10   5   9] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 76.3%, DoS: 95.7%, Probe: 95.0%, R2L: 98.2%, U2R: 93.8%|
# |Def Entropy: 0.2886| Att Entropy: 3.5254|
# Epoch 93, Average Attack Accuracy: 95.60%
#
# |Epoch 093/100| Time: 30.51|
# |Def Reward: 1422| Att Reward: -570|
# |Def Estimated: [459 459 262 271 149]| Att Labels: [600 438 209 212 141]
# |Def Policy Loss: -0.0101| Def Value Loss: 4.7982| Def Grad Norm: 49.6459|
# |Att Policy Loss: -0.0332| Att Value Loss: 1.3454| Att Grad Norm: 6.1623|
# |Def Correct: [446 417 204 211 127] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [154  21   5   1  14] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 74.3%, DoS: 95.2%, Probe: 97.6%, R2L: 99.5%, U2R: 90.1%|
# |Def Entropy: 0.2924| Att Entropy: 3.5260|
# Epoch 94, Average Attack Accuracy: 95.05%
#
# |Epoch 094/100| Time: 30.47|
# |Def Reward: 1470| Att Reward: -558|
# |Def Estimated: [437 454 242 299 168]| Att Labels: [575 431 195 245 154]
# |Def Policy Loss: -0.0079| Def Value Loss: 4.7068| Def Grad Norm: 48.8719|
# |Att Policy Loss: -0.0361| Att Value Loss: 1.5869| Att Grad Norm: 6.1191|
# |Def Correct: [426 404 190 242 139] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [149  27   5   3  15] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 74.1%, DoS: 93.7%, Probe: 97.4%, R2L: 98.8%, U2R: 90.3%|
# |Def Entropy: 0.2943| Att Entropy: 3.5299|
# Epoch 95, Average Attack Accuracy: 94.54%
#
# |Epoch 095/100| Time: 30.48|
# |Def Reward: 1519| Att Reward: -583|
# |Def Estimated: [436 467 220 291 186]| Att Labels: [540 448 206 234 172]
# |Def Policy Loss: -0.0073| Def Value Loss: 4.3092| Def Grad Norm: 48.7683|
# |Att Policy Loss: -0.0306| Att Value Loss: 1.2102| Att Grad Norm: 5.0893|
# |Def Correct: [420 424 187 232 161] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [120  24  19   2  11] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 77.8%, DoS: 94.6%, Probe: 90.8%, R2L: 99.1%, U2R: 93.6%|
# |Def Entropy: 0.2873| Att Entropy: 3.5343|
# Epoch 96, Average Attack Accuracy: 94.34%
#
# |Epoch 096/100| Time: 30.62|
# |Def Reward: 1437| Att Reward: -534|
# |Def Estimated: [420 458 269 288 165]| Att Labels: [565 423 226 234 152]
# |Def Policy Loss: -0.0104| Def Value Loss: 4.2484| Def Grad Norm: 49.9228|
# |Att Policy Loss: -0.0293| Att Value Loss: 1.2229| Att Grad Norm: 5.7872|
# |Def Correct: [403 394 212 230 140] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [162  29  14   4  12] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 71.3%, DoS: 93.1%, Probe: 93.8%, R2L: 98.3%, U2R: 92.1%|
# |Def Entropy: 0.2831| Att Entropy: 3.5294|
# Epoch 97, Average Attack Accuracy: 95.86%
#
# |Epoch 097/100| Time: 30.79|
# |Def Reward: 1506| Att Reward: -584|
# |Def Estimated: [439 439 250 289 183]| Att Labels: [563 417 216 240 164]
# |Def Policy Loss: -0.0095| Def Value Loss: 3.3708| Def Grad Norm: 43.1099|
# |Att Policy Loss: -0.0421| Att Value Loss: 1.0588| Att Grad Norm: 5.4613|
# |Def Correct: [426 394 208 237 154] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [137  23   8   3  10] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 75.7%, DoS: 94.5%, Probe: 96.3%, R2L: 98.8%, U2R: 93.9%|
# |Def Entropy: 0.2894| Att Entropy: 3.5345|
# Epoch 98, Average Attack Accuracy: 95.18%
#
# |Epoch 098/100| Time: 30.83|
# |Def Reward: 1488| Att Reward: -565|
# |Def Estimated: [437 433 228 333 169]| Att Labels: [567 418 209 266 140]
# |Def Policy Loss: -0.0112| Def Value Loss: 5.1309| Def Grad Norm: 54.7625|
# |Att Policy Loss: -0.0325| Att Value Loss: 1.5662| Att Grad Norm: 6.1454|
# |Def Correct: [419 391 198 263 131] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [148  27  11   3   9] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 73.9%, DoS: 93.5%, Probe: 94.7%, R2L: 98.9%, U2R: 93.6%|
# |Def Entropy: 0.3027| Att Entropy: 3.5419|
# Epoch 99, Average Attack Accuracy: 95.37%
#
# |Epoch 099/100| Time: 30.52|
# |Def Reward: 1478| Att Reward: -580|
# |Def Estimated: [463 422 232 291 192]| Att Labels: [586 405 218 236 155]
# |Def Policy Loss: -0.0090| Def Value Loss: 4.4571| Def Grad Norm: 50.2560|
# |Att Policy Loss: -0.0320| Att Value Loss: 1.3265| Att Grad Norm: 6.1061|
# |Def Correct: [447 384 202 234 147] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Def Incorrect: [139  21  16   2   8] (['normal', 'DoS', 'Probe', 'R2L', 'U2R'])|
# |Class Accuracies: normal: 76.3%, DoS: 94.8%, Probe: 92.7%, R2L: 99.2%, U2R: 94.8%|
# |Def Entropy: 0.2782| Att Entropy: 3.5531|
# Training and visualization done. Proceed to evaluation/test as next step.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os


# === Plot Reward and Loss ===
os.makedirs("results", exist_ok=True)
plt.figure(figsize=(10, 8))
plt.subplot(211)
plt.plot(def_reward_chain, label='Defense')
plt.plot(att_reward_chain, label='Attack')
plt.title('Total Reward by Episode')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

plt.subplot(212)
plt.plot(def_loss_chain, label='Defense')
plt.plot(att_loss_chain, label='Attack')
plt.title('Loss by Episode')
plt.xlabel('Episode')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig('results/train_adv.eps', format='eps', dpi=1000)
plt.close()

# === Plot histogram of 23 attack_names ===
bins = np.arange(len(env.attack_names)) - 0.5
plt.figure(figsize=[20, 6])
plt.suptitle("Attacks Distribution Throughout Episodes", fontsize=14)
selected_epochs = [0, 25, 50, 75, len(attacks_by_epoch)-1]
for idx, epoch in enumerate(selected_epochs):
    plt.subplot(1, 5, idx+1)
    plt.hist(attacks_by_epoch[epoch].flatten(), bins=bins, width=0.8, align='mid', color='skyblue')
    plt.xlabel(f"Epoch {epoch}", fontsize=10)
    plt.xticks(range(len(env.attack_names)), env.attack_names, rotation=90, fontsize=8)
    plt.ylabel("Count", fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('results/Attacks_distribution.svg', format='svg', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()

# === Create 5-class mapped attacker counts ===
attack_labels_list = []
for epoch_attacks in attacks_by_epoch:
    sample_mapped = [env.attack_types.index(env.attack_map[env.attack_names[a]]) for a in epoch_attacks.flatten()]
    counts = [sample_mapped.count(i) for i in range(len(env.attack_types))]
    attack_labels_list.append(counts)

# === Plot 5-class attacker distribution across epochs ===
plt.figure(figsize=[20, 6])
plt.suptitle("Mapped Attacks Distribution Throughout Episodes", fontsize=14)
selected_epochs = list(range(0, len(attack_labels_list), 10))
for idx, epoch in enumerate(selected_epochs):
    plt.subplot(2, 5, idx+1)
    plt.bar(range(len(env.attack_types)), attack_labels_list[epoch], tick_label=env.attack_types, color='lightgreen')
    plt.xlabel(f"Epoch {epoch}", fontsize=10)
    plt.xticks(rotation=45, fontsize=10)
    plt.ylabel("Count", fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('results/Attacks_mapped_distribution.svg', format='svg', dpi=1000, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
